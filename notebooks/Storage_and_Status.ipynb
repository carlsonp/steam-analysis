# %%
import sys, os
from pymongo import MongoClient

from plotly.offline import init_notebook_mode, iplot
from plotly.graph_objs import *

# https://stackoverflow.com/questions/41323423/plotly-inside-jupyter-notebook-python
init_notebook_mode(connected=True) # initiate notebook for offline plot

import pandas as pd
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
sys.path.append("..")
import config # ../config.py

# run on raspberrypi3 Mongo database
#config.mongodb_ip = "192.168.1.224"
# run on Asus laptop Mongo database
#config.mongodb_ip = "192.168.1.124"

client = MongoClient(host=config.mongodb_ip, port=config.mongodb_port)
db = client['steam']

# %% [markdown]
# ## Failed appids excluded from future attempts or analysis

# %%
failed_appids_df = pd.DataFrame(list(db['apps'].find({"failureCount": {"$gte":3}}, {"appid":1,"name":1,"_id":False})))
failed_appids_df
# Out:
#          appid                                               name
# 0        12630                                Legend: Hand of God
# 1        15310                    The Settlers: Heritage of Kings
# 2        19930     The Settlers: Rise of an Empire Gold Edition
# 3        23330                              The Last Remnant Demo
# 4        33910                                             Arma 2
# 5        33220             Tom Clancy's Splinter Cell: Conviction
# 6        63600                                           realMyst
# 7        81675                          Ticket to Ride Trailer DE
# 8        81674                          Ticket to Ride Trailer EN
# 9        81676                          Ticket to Ride Trailer FR
# 10      210897              Crusader Kings II: African Portraits
# 11      227240                                   Construct 2 Free
# 12      233250                             Planetary Annihilation
# 13           7                                       Steam Client
# 14         215                               Source SDK Base 2006
# 15         852                                    ValveTestApp852
# 16         972                 Sam & Max 105: Reality 2.0 Trailer
# 17        1259                                      Killing Floor
# 18        1306                     SiN Episodes: Emergence German
# 19        1635                  Disciples II ROTE Scenario Editor
# 20        2580                       Vigil: Blood Bitterness Demo
# 21        3160                              A Farewell to Dragons
# 22        3472                    Bookworm Adventures Deluxe Demo
# 23        4270                      RACE 07 Demo Dedicated Server
# 24          90                         Half-Life Dedicated Server
# 25         100      Counter-Strike: Condition Zero Deleted Scenes
# 26         644                           Portal 2 Publishing Tool
# 27         756                                  Steam Big Picture
# 28         944                                   Left4Dead Teaser
# 29         989               Juiced 2 - Hot Import Nights Trailer
# ...        ...                                                ...
# 10175  1071470                Planetes Community Dedicated Server
# 10176   870279                                Shazam Movie Part 2
# 10177  1056920  Dream Beach - Mallorca | VR Nature Experience ...
# 10178  1016550  Nelke & the LA: Facility Landmark "Sophie's st...
# 10179  1054873                             Ninja Mime Johnny Cage
# 10180  1054870                                   Kold War Skarlet
# 10181  1054871                                    Cangaceiro Kano
# 10182  1054872                                Gold Demon Scorpion
# 10183  1062511           Winning Post 9 追加コンテンツ 世界への飛翔 購入権セット 全４頭
# 10184  1062514            Winning Post 9 追加コンテンツ 究極の大器 購入権セット 全３頭
# 10185  1062512             Winning Post 9 追加コンテンツ 最強古馬 購入権セット 全２頭
# 10186  1062515             Winning Post 9 追加コンテンツ 名馬購入権フルセット 全１８頭
# 10187  1062510            Winning Post 9 追加コンテンツ 牡馬三冠馬 購入権セット 全３頭
# 10188  1062513            Winning Post 9 追加コンテンツ 歴史的名牝 購入権セット 全６頭
# 10189   997163  BLACK CLOVER: QUARTET KNIGHTS VO: “Yami Sukehi...
# 10190  1079220  Starlink: Battle for Atlas - Standard Edition ...
# 10191  1079240  Starlink: Battle for Atlas - Collection pack 1...
# 10192  1075452  Starlink: Battle for Atlas - Collection pack 1...
# 10193  1075450  Starlink: Battle for Atlas - Standard Edition ...
# 10194  1079221  Starlink: Battle for Atlas - Deluxe Edition - ...
# 10195  1075451  Starlink: Battle for Atlas - Deluxe Edition - ...
# 10196  1075453  Starlink: Battle for Atlas - Collection pack 2...
# 10197   629800                           MORDHAU Dedicated Server
# 10198  1080910               Kickstarter Skin - GSO Laser Weapons
# 10199  1080911            Kickstarter Skin - Mining Crew Hardcore
# 10200  1020570    DRAGON BALL FighterZ - Commentator Voice Pack 2
# 10201  1020571    DRAGON BALL FighterZ - Commentator Voice Pack 3
# 10202  1020572    DRAGON BALL FighterZ - Commentator Voice Pack 4
# 10203   925102      The Elder Scrolls Online - Rahd-m'Athra Horse
# 10204   982260                     Blazing Beaks Character Editor
#
# [10205 rows x 2 columns]

# %%
grouped_df = db['apps'].aggregate([
{"$match":
    {"$or": [{"failureCount": {"$lt": 3}}, {"failureCount": {"$exists": False}}]}
},
{"$group":  {"_id": {"$dateToString": {"format": "%Y-%m-%d", "date": "$updated_date"}},
             "count" : { "$sum" : 1} } },
{"$sort": {"_id": 1}}
])

grouped_df = pd.DataFrame(list(grouped_df))
grouped_df.rename(columns={grouped_df.columns[0] : 'updated_date'}, inplace=True)
grouped_df
# Out:
#    updated_date  count
# 0    2019-04-15    436
# 1    2019-04-16   3587
# 2    2019-04-17   3478
# 3    2019-04-18   3537
# 4    2019-04-19   3780
# 5    2019-04-20   1749
# 6    2019-04-21   2993
# 7    2019-04-22   3003
# 8    2019-04-23   3311
# 9    2019-04-24   3553
# 10   2019-04-25   3550
# 11   2019-04-26   3070
# 12   2019-04-27   3016
# 13   2019-04-28   3846
# 14   2019-04-29    500
# 15   2019-04-30   2984
# 16   2019-05-01   2213
# 17   2019-05-02   2498
# 18   2019-05-03   1212
# 19   2019-05-04    546
# 20   2019-05-05   3975
# 21   2019-05-06   2205
# 22   2019-05-07   2990
# 23   2019-05-08   2509
# 24   2019-05-09   2154
# 25   2019-05-10   2042
# 26   2019-05-11    499

# %% [markdown]
# ## Large numbers of old AppID entries means `refreshsteam.py` needs to be run.  This excludes consistently failed appids.

# %%
# https://plot.ly/python/bar-charts/

data = [Bar(
        x=grouped_df['updated_date'],
        y=grouped_df['count']
    )]

layout = Layout(
        title='AppIDs By Last Updated Date',
        xaxis=dict(
            title='Date'
        ),
        yaxis=dict(
            title='Count'
        )
    )

fig = Figure(data=data, layout=layout)

iplot(fig)
# Out:
# <div id="9ff154f0-068d-455c-b44c-56a45fdf942d" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("9ff154f0-068d-455c-b44c-56a45fdf942d", [{"y": [436, 3587, 3478, 3537, 3780, 1749, 2993, 3003, 3311, 3553, 3550, 3070, 3016, 3846, 500, 2984, 2213, 2498, 1212, 546, 3975, 2205, 2990, 2509, 2154, 2042, 499], "type": "bar", "uid": "205e4ec4-bad0-4a78-b5ac-c9dad20d19f8", "x": ["2019-04-15", "2019-04-16", "2019-04-17", "2019-04-18", "2019-04-19", "2019-04-20", "2019-04-21", "2019-04-22", "2019-04-23", "2019-04-24", "2019-04-25", "2019-04-26", "2019-04-27", "2019-04-28", "2019-04-29", "2019-04-30", "2019-05-01", "2019-05-02", "2019-05-03", "2019-05-04", "2019-05-05", "2019-05-06", "2019-05-07", "2019-05-08", "2019-05-09", "2019-05-10", "2019-05-11"]}], {"title": {"text": "AppIDs By Last Updated Date"}, "xaxis": {"title": {"text": "Date"}}, "yaxis": {"title": {"text": "Count"}}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("9ff154f0-068d-455c-b44c-56a45fdf942d"));});</script>

# %%
grouped_df = db['pricehistory'].aggregate([
{"$match": {}},
{"$group":  {"_id": {"$dateToString": {"format": "%Y-%m-%d", "date": "$date"}},
             "count" : { "$sum" : 1} } },
{"$sort": {"_id": 1}}
])

grouped_df = pd.DataFrame(list(grouped_df))
grouped_df.rename(columns={grouped_df.columns[0] : 'date'}, inplace=True)
grouped_df
# Out:
#            date  count
# 0    2018-09-04   8215
# 1    2018-09-05  43441
# 2    2018-09-06  37421
# 3    2018-09-07  23655
# 4    2018-09-08  37188
# 5    2018-09-10   2963
# 6    2018-09-11  45999
# 7    2018-09-12  20210
# 8    2018-09-13    269
# 9    2018-09-14  37390
# 10   2018-09-15  37650
# 11   2018-09-17  13770
# 12   2018-09-18  23910
# 13   2018-09-20  45652
# 14   2018-09-22  36531
# 15   2018-09-24   6238
# 16   2018-09-25  34293
# 17   2018-09-27  36969
# 18   2018-09-28  36974
# 19   2018-09-30   9130
# 20   2018-10-01  27797
# 21   2018-10-03  36964
# 22   2018-10-05  37018
# 23   2018-10-06  23097
# 24   2018-10-07  13902
# 25   2018-10-09  37005
# 26   2018-10-12  37128
# 27   2018-10-14  37054
# 28   2018-10-17  37148
# 29   2018-10-20  37170
# ..          ...    ...
# 161  2019-04-12   2147
# 162  2019-04-13  45883
# 163  2019-04-14   2771
# 164  2019-04-15   2427
# 165  2019-04-16   2645
# 166  2019-04-17   2433
# 167  2019-04-18   2525
# 168  2019-04-19   2667
# 169  2019-04-20   1245
# 170  2019-04-21  31751
# 171  2019-04-22  14328
# 172  2019-04-23   2318
# 173  2019-04-24  46525
# 174  2019-04-25   2111
# 175  2019-04-26  45728
# 176  2019-04-27   2112
# 177  2019-04-28  47008
# 178  2019-04-29    381
# 179  2019-04-30   2108
# 180  2019-05-01   1473
# 181  2019-05-02  47075
# 182  2019-05-03    798
# 183  2019-05-04  44655
# 184  2019-05-05   2854
# 185  2019-05-06  45935
# 186  2019-05-07   2182
# 187  2019-05-08   1842
# 188  2019-05-09  45959
# 189  2019-05-10   1327
# 190  2019-05-11    340
#
# [191 rows x 2 columns]

# %% [markdown]
# ## This is historical data from the `pricehistory` Mongo collection.  This is run roughly every 48 hours.

# %%
# https://plot.ly/python/bar-charts/

data = [Bar(
        x=grouped_df['date'],
        y=grouped_df['count']
    )]

layout = Layout(
        title='Distribution of Price History',
        xaxis=dict(
            title='Date'
        ),
        yaxis=dict(
            title='Records Count'
        )
    )

fig = Figure(data=data, layout=layout)

iplot(fig)
# Out:
# <div id="87cce6e0-6277-40bf-ae2b-23b1b7b84856" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("87cce6e0-6277-40bf-ae2b-23b1b7b84856", [{"y": [8215, 43441, 37421, 23655, 37188, 2963, 45999, 20210, 269, 37390, 37650, 13770, 23910, 45652, 36531, 6238, 34293, 36969, 36974, 9130, 27797, 36964, 37018, 23097, 13902, 37005, 37128, 37054, 37148, 37170, 37195, 22490, 14330, 37262, 3876, 33416, 37490, 37216, 36870, 19257, 18066, 37280, 37305, 37384, 37377, 37363, 37422, 27672, 9761, 37403, 37461, 37531, 37496, 37484, 37522, 24521, 13019, 37514, 36924, 37700, 37622, 26636, 37138, 37607, 37691, 37726, 37724, 37721, 37718, 52, 42881, 9816, 20144, 7351, 3837, 2379, 12169, 44131, 2498, 44162, 3125, 24231, 3347, 54641, 3174, 44303, 3107, 43548, 2752, 4691, 42081, 2705, 44010, 2108, 43241, 2847, 43947, 2901, 2804, 44353, 3091, 44531, 2826, 44439, 2850, 44692, 2889, 44519, 2824, 44208, 2317, 2506, 44264, 1560, 44668, 3169, 44793, 2755, 2513, 3032, 44944, 2821, 44944, 2870, 45290, 2728, 45118, 2666, 45160, 2526, 45256, 1985, 1670, 2847, 45740, 2696, 45413, 45074, 2655, 45645, 1917, 2140, 2776, 45296, 2287, 23222, 1123, 2697, 535, 26883, 1855, 2441, 2453, 44723, 1709, 2449, 69998, 2654, 46042, 2965, 46165, 2147, 45883, 2771, 2427, 2645, 2433, 2525, 2667, 1245, 31751, 14328, 2318, 46525, 2111, 45728, 2112, 47008, 381, 2108, 1473, 47075, 798, 44655, 2854, 45935, 2182, 1842, 45959, 1327, 340], "type": "bar", "uid": "02ddf845-8b59-49fa-ad6f-009c39806672", "x": ["2018-09-04", "2018-09-05", "2018-09-06", "2018-09-07", "2018-09-08", "2018-09-10", "2018-09-11", "2018-09-12", "2018-09-13", "2018-09-14", "2018-09-15", "2018-09-17", "2018-09-18", "2018-09-20", "2018-09-22", "2018-09-24", "2018-09-25", "2018-09-27", "2018-09-28", "2018-09-30", "2018-10-01", "2018-10-03", "2018-10-05", "2018-10-06", "2018-10-07", "2018-10-09", "2018-10-12", "2018-10-14", "2018-10-17", "2018-10-20", "2018-10-24", "2018-10-25", "2018-10-26", "2018-10-29", "2018-10-31", "2018-11-01", "2018-11-03", "2018-11-06", "2018-11-08", "2018-11-09", "2018-11-10", "2018-11-11", "2018-11-14", "2018-11-16", "2018-11-17", "2018-11-20", "2018-11-22", "2018-11-23", "2018-11-24", "2018-11-25", "2018-11-28", "2018-11-30", "2018-12-02", "2018-12-04", "2018-12-06", "2018-12-07", "2018-12-08", "2018-12-10", "2018-12-12", "2018-12-14", "2018-12-17", "2018-12-19", "2018-12-21", "2018-12-24", "2018-12-25", "2018-12-28", "2018-12-30", "2019-01-01", "2019-01-03", "2019-01-05", "2019-01-06", "2019-01-07", "2019-01-08", "2019-01-09", "2019-01-10", "2019-01-13", "2019-01-14", "2019-01-15", "2019-01-16", "2019-01-17", "2019-01-18", "2019-01-19", "2019-01-20", "2019-01-21", "2019-01-22", "2019-01-23", "2019-01-24", "2019-01-25", "2019-01-26", "2019-01-27", "2019-01-28", "2019-01-29", "2019-01-30", "2019-01-31", "2019-02-01", "2019-02-02", "2019-02-03", "2019-02-05", "2019-02-06", "2019-02-07", "2019-02-08", "2019-02-09", "2019-02-10", "2019-02-11", "2019-02-12", "2019-02-13", "2019-02-14", "2019-02-15", "2019-02-16", "2019-02-17", "2019-02-18", "2019-02-19", "2019-02-20", "2019-02-21", "2019-02-22", "2019-02-23", "2019-02-24", "2019-02-25", "2019-02-26", "2019-02-27", "2019-02-28", "2019-03-01", "2019-03-02", "2019-03-03", "2019-03-04", "2019-03-05", "2019-03-06", "2019-03-07", "2019-03-08", "2019-03-09", "2019-03-10", "2019-03-11", "2019-03-12", "2019-03-13", "2019-03-14", "2019-03-15", "2019-03-16", "2019-03-18", "2019-03-19", "2019-03-20", "2019-03-21", "2019-03-22", "2019-03-23", "2019-03-24", "2019-03-25", "2019-03-26", "2019-03-27", "2019-03-28", "2019-03-29", "2019-03-30", "2019-03-31", "2019-04-02", "2019-04-03", "2019-04-04", "2019-04-05", "2019-04-06", "2019-04-07", "2019-04-08", "2019-04-09", "2019-04-10", "2019-04-11", "2019-04-12", "2019-04-13", "2019-04-14", "2019-04-15", "2019-04-16", "2019-04-17", "2019-04-18" ...

# %%
grouped_df = db['steamusers'].aggregate([
{"$match": {}},
{"$group":  {"_id": {"$dateToString": {"format": "%Y-%m-%d", "date": "$date"}},
             "count" : { "$sum" : 1} } },
{"$sort": {"_id": 1}}
])

grouped_df = pd.DataFrame(list(grouped_df))
grouped_df.rename(columns={grouped_df.columns[0] : 'date'}, inplace=True)
grouped_df
# Out:
#            date  count
# 0    2018-12-19    119
# 1    2018-12-20    340
# 2    2018-12-21    751
# 3    2018-12-22   1021
# 4    2018-12-23    932
# 5    2018-12-24    980
# 6    2018-12-25    938
# 7    2018-12-26    924
# 8    2018-12-27   1106
# 9    2018-12-28   1287
# 10   2018-12-29   1219
# 11   2018-12-30   1176
# 12   2018-12-31   1214
# 13   2019-01-01    943
# 14   2019-01-03    346
# 15   2019-01-05    617
# 16   2019-01-06    717
# 17   2019-01-07    134
# 18   2019-01-08    170
# 19   2019-01-09    351
# 20   2019-01-10     62
# 21   2019-01-11    267
# 22   2019-01-12    363
# 23   2019-01-13    409
# 24   2019-01-14    631
# 25   2019-01-15    626
# 26   2019-01-16    628
# 27   2019-01-17    597
# 28   2019-01-18    600
# 29   2019-01-19    627
# ..          ...    ...
# 112  2019-04-12    501
# 113  2019-04-13    500
# 114  2019-04-14    624
# 115  2019-04-15    630
# 116  2019-04-16    627
# 117  2019-04-17    628
# 118  2019-04-18    615
# 119  2019-04-19    513
# 120  2019-04-20    778
# 121  2019-04-21    874
# 122  2019-04-22    627
# 123  2019-04-23    624
# 124  2019-04-24    637
# 125  2019-04-25    636
# 126  2019-04-26    628
# 127  2019-04-27    578
# 128  2019-04-28    552
# 129  2019-04-29    608
# 130  2019-04-30    863
# 131  2019-05-01    848
# 132  2019-05-02    459
# 133  2019-05-03    465
# 134  2019-05-04    631
# 135  2019-05-05    623
# 136  2019-05-06    630
# 137  2019-05-07    711
# 138  2019-05-08    709
# 139  2019-05-09    647
# 140  2019-05-10    345
# 141  2019-05-11     15
#
# [142 rows x 2 columns]

# %% [markdown]
# ## These are the number of records we have per day for the `steamusers` Mongo collection.  This is created using the `steamusers.py` script.

# %%
# https://plot.ly/python/bar-charts/

data = [Bar(
        x=grouped_df['date'],
        y=grouped_df['count']
    )]

layout = Layout(
        title='Distribution of Records Per Day for steamusers',
        xaxis=dict(
            title='Date'
        ),
        yaxis=dict(
            title='Records Count'
        )
    )

fig = Figure(data=data, layout=layout)

iplot(fig)
# Out:
# <div id="8ba252a5-0ae9-4109-8826-204ad7d92101" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("8ba252a5-0ae9-4109-8826-204ad7d92101", [{"y": [119, 340, 751, 1021, 932, 980, 938, 924, 1106, 1287, 1219, 1176, 1214, 943, 346, 617, 717, 134, 170, 351, 62, 267, 363, 409, 631, 626, 628, 597, 600, 627, 629, 630, 628, 629, 754, 755, 622, 623, 621, 621, 626, 629, 628, 520, 348, 452, 625, 620, 622, 622, 625, 629, 624, 631, 627, 626, 624, 600, 607, 630, 633, 642, 635, 628, 626, 563, 506, 563, 622, 604, 640, 643, 630, 628, 631, 629, 630, 641, 642, 701, 728, 620, 622, 625, 627, 338, 297, 586, 625, 567, 565, 625, 628, 627, 470, 467, 460, 427, 593, 323, 13, 295, 619, 871, 868, 716, 724, 640, 622, 620, 623, 625, 501, 500, 624, 630, 627, 628, 615, 513, 778, 874, 627, 624, 637, 636, 628, 578, 552, 608, 863, 848, 459, 465, 631, 623, 630, 711, 709, 647, 345, 15], "type": "bar", "uid": "5592d2d8-208b-4d8e-b0cc-1a02605a618f", "x": ["2018-12-19", "2018-12-20", "2018-12-21", "2018-12-22", "2018-12-23", "2018-12-24", "2018-12-25", "2018-12-26", "2018-12-27", "2018-12-28", "2018-12-29", "2018-12-30", "2018-12-31", "2019-01-01", "2019-01-03", "2019-01-05", "2019-01-06", "2019-01-07", "2019-01-08", "2019-01-09", "2019-01-10", "2019-01-11", "2019-01-12", "2019-01-13", "2019-01-14", "2019-01-15", "2019-01-16", "2019-01-17", "2019-01-18", "2019-01-19", "2019-01-20", "2019-01-21", "2019-01-22", "2019-01-23", "2019-01-24", "2019-01-25", "2019-01-26", "2019-01-27", "2019-01-28", "2019-01-29", "2019-01-30", "2019-01-31", "2019-02-01", "2019-02-02", "2019-02-03", "2019-02-04", "2019-02-05", "2019-02-06", "2019-02-07", "2019-02-08", "2019-02-09", "2019-02-10", "2019-02-11", "2019-02-12", "2019-02-13", "2019-02-14", "2019-02-15", "2019-02-16", "2019-02-17", "2019-02-18", "2019-02-19", "2019-02-20", "2019-02-21", "2019-02-22", "2019-02-23", "2019-02-24", "2019-02-25", "2019-02-26", "2019-02-27", "2019-02-28", "2019-03-01", "2019-03-02", "2019-03-03", "2019-03-04", "2019-03-05", "2019-03-06", "2019-03-07", "2019-03-08", "2019-03-09", "2019-03-10", "2019-03-11", "2019-03-12", "2019-03-13", "2019-03-14", "2019-03-15", "2019-03-16", "2019-03-17", "2019-03-18", "2019-03-19", "2019-03-20", "2019-03-21", "2019-03-22", "2019-03-23", "2019-03-24", "2019-03-25", "2019-03-26", "2019-03-27", "2019-03-28", "2019-03-29", "2019-03-30", "2019-03-31", "2019-04-01", "2019-04-02", "2019-04-03", "2019-04-04", "2019-04-05", "2019-04-06", "2019-04-07", "2019-04-08", "2019-04-09", "2019-04-10", "2019-04-11", "2019-04-12", "2019-04-13", "2019-04-14", "2019-04-15", "2019-04-16", "2019-04-17", "2019-04-18", "2019-04-19", "2019-04-20", "2019-04-21", "2019-04-22", "2019-04-23", "2019-04-24", "2019-04-25", "2019-04-26", "2019-04-27", "2019-04-28", "2019-04-29", "2019-04-30", "2019-05-01", "2019-05-02", "2019-05-03", "2019-05-04", "2019-05-05", "2019-05-06", "2019-05-07", "2019-05-08", "2019-05-09", "2019-05-10", "2019-05-11"]}], {"title": {"text": "Distribution of Records Per Day for steamusers"}, "xaxis": {"title": {"text": "Date"}}, "yaxis": {"title": {"text": "Records Count"}}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("8ba252a5-0ae9-4109-8826-204ad7d92101"));});</script>

# %%
grouped_df = db['topgames'].aggregate([
{"$match": {}},
{"$group":  {"_id": {"$dateToString": {"format": "%Y-%m-%d", "date": "$date"}},
             "count" : { "$sum" : 1} } },
{"$sort": {"_id": 1}}
])

grouped_df = pd.DataFrame(list(grouped_df))
grouped_df.rename(columns={grouped_df.columns[0] : 'date'}, inplace=True)
grouped_df
# Out:
#            date  count
# 0    2019-01-08    300
# 1    2019-01-09   2300
# 2    2019-01-10    100
# 3    2019-01-13   4000
# 4    2019-01-14   9000
# 5    2019-01-15   8400
# 6    2019-01-16   9200
# 7    2019-01-17   8500
# 8    2019-01-18   9100
# 9    2019-01-19   5200
# 10   2019-01-20   9200
# 11   2019-01-21   8500
# 12   2019-01-22   9000
# 13   2019-01-23   8400
# 14   2019-01-24   9100
# 15   2019-01-25   8600
# 16   2019-01-26   8700
# 17   2019-01-27   8600
# 18   2019-01-28   8200
# 19   2019-01-29   8700
# 20   2019-01-30   8100
# 21   2019-01-31   8600
# 22   2019-02-01   8200
# 23   2019-02-02   8600
# 24   2019-02-03   7000
# 25   2019-02-05   4100
# 26   2019-02-06   8700
# 27   2019-02-07   8200
# 28   2019-02-08   8500
# 29   2019-02-09   8200
# ..          ...    ...
# 90   2019-04-12   8700
# 91   2019-04-13   8000
# 92   2019-04-14   8500
# 93   2019-04-15   8100
# 94   2019-04-16   8700
# 95   2019-04-17   8200
# 96   2019-04-18   8200
# 97   2019-04-19   8400
# 98   2019-04-20   3700
# 99   2019-04-21   8000
# 100  2019-04-22   8600
# 101  2019-04-23   8600
# 102  2019-04-24   7800
# 103  2019-04-25   8600
# 104  2019-04-26   7200
# 105  2019-04-27   7000
# 106  2019-04-28   8100
# 107  2019-04-29   2300
# 108  2019-04-30   7000
# 109  2019-05-01   6400
# 110  2019-05-02   5600
# 111  2019-05-03   4000
# 112  2019-05-04   3400
# 113  2019-05-05   8200
# 114  2019-05-06   8000
# 115  2019-05-07   7800
# 116  2019-05-08   7100
# 117  2019-05-09   7000
# 118  2019-05-10   4400
# 119  2019-05-11   1400
#
# [120 rows x 2 columns]

# %% [markdown]
# ## These are the number of entries we have per day for the `topgames` Mongo collection.  Each query returns the current top 100 games being played.  This is run every 15 minutes.

# %%
# https://plot.ly/python/bar-charts/

data = [Bar(
        x=grouped_df['date'],
        y=grouped_df['count']
    )]

layout = Layout(
        title='Distribution of Records Per Day for topgames',
        xaxis=dict(
            title='Date'
        ),
        yaxis=dict(
            title='Records Count'
        )
    )

fig = Figure(data=data, layout=layout)

iplot(fig)
# Out:
# <div id="87a4d599-ab20-4558-b649-119e74fd2af8" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("87a4d599-ab20-4558-b649-119e74fd2af8", [{"y": [300, 2300, 100, 4000, 9000, 8400, 9200, 8500, 9100, 5200, 9200, 8500, 9000, 8400, 9100, 8600, 8700, 8600, 8200, 8700, 8100, 8600, 8200, 8600, 7000, 4100, 8700, 8200, 8500, 8200, 8600, 8300, 8600, 8100, 8700, 8100, 8700, 7600, 7400, 8700, 8100, 8700, 8100, 8500, 8200, 8600, 8600, 8600, 8200, 8700, 8100, 8600, 8100, 8700, 8200, 8600, 8100, 8600, 8100, 8700, 8600, 8600, 8000, 8600, 8000, 600, 7200, 8700, 8100, 6400, 7100, 8300, 8200, 7900, 1800, 4600, 8700, 700, 8400, 7000, 8300, 8700, 7500, 8600, 8600, 5000, 8600, 8200, 8600, 8100, 8700, 8000, 8500, 8100, 8700, 8200, 8200, 8400, 3700, 8000, 8600, 8600, 7800, 8600, 7200, 7000, 8100, 2300, 7000, 6400, 5600, 4000, 3400, 8200, 8000, 7800, 7100, 7000, 4400, 1400], "type": "bar", "uid": "05067830-e1eb-410a-b670-a5c41cf3d1d6", "x": ["2019-01-08", "2019-01-09", "2019-01-10", "2019-01-13", "2019-01-14", "2019-01-15", "2019-01-16", "2019-01-17", "2019-01-18", "2019-01-19", "2019-01-20", "2019-01-21", "2019-01-22", "2019-01-23", "2019-01-24", "2019-01-25", "2019-01-26", "2019-01-27", "2019-01-28", "2019-01-29", "2019-01-30", "2019-01-31", "2019-02-01", "2019-02-02", "2019-02-03", "2019-02-05", "2019-02-06", "2019-02-07", "2019-02-08", "2019-02-09", "2019-02-10", "2019-02-11", "2019-02-12", "2019-02-13", "2019-02-14", "2019-02-15", "2019-02-16", "2019-02-17", "2019-02-18", "2019-02-19", "2019-02-20", "2019-02-21", "2019-02-22", "2019-02-23", "2019-02-24", "2019-02-25", "2019-02-26", "2019-02-27", "2019-02-28", "2019-03-01", "2019-03-02", "2019-03-03", "2019-03-04", "2019-03-05", "2019-03-06", "2019-03-07", "2019-03-08", "2019-03-09", "2019-03-10", "2019-03-11", "2019-03-12", "2019-03-13", "2019-03-14", "2019-03-15", "2019-03-16", "2019-03-17", "2019-03-18", "2019-03-19", "2019-03-20", "2019-03-21", "2019-03-22", "2019-03-23", "2019-03-24", "2019-03-25", "2019-03-26", "2019-03-27", "2019-03-28", "2019-03-29", "2019-03-30", "2019-03-31", "2019-04-02", "2019-04-03", "2019-04-04", "2019-04-05", "2019-04-06", "2019-04-07", "2019-04-08", "2019-04-09", "2019-04-10", "2019-04-11", "2019-04-12", "2019-04-13", "2019-04-14", "2019-04-15", "2019-04-16", "2019-04-17", "2019-04-18", "2019-04-19", "2019-04-20", "2019-04-21", "2019-04-22", "2019-04-23", "2019-04-24", "2019-04-25", "2019-04-26", "2019-04-27", "2019-04-28", "2019-04-29", "2019-04-30", "2019-05-01", "2019-05-02", "2019-05-03", "2019-05-04", "2019-05-05", "2019-05-06", "2019-05-07", "2019-05-08", "2019-05-09", "2019-05-10", "2019-05-11"]}], {"title": {"text": "Distribution of Records Per Day for topgames"}, "xaxis": {"title": {"text": "Date"}}, "yaxis": {"title": {"text": "Records Count"}}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("87a4d599-ab20-4558-b649-119e74fd2af8"));});</script>

# %% [markdown]
# ## Storage and disk usage information

# %%
# https://stackoverflow.com/questions/1094841/reusable-library-to-get-human-readable-version-of-file-size
def sizeof_fmt(num, suffix='B'):
    for unit in ['','Ki','Mi','Gi','Ti','Pi','Ei','Zi']:
        if abs(num) < 1024.0:
            return "%3.1f %s%s" % (num, unit, suffix)
        num /= 1024.0
    return "%.1f %s%s" % (num, 'Yi', suffix)

for collection in db.list_collection_names():
    stats = db.command("collstats", str(collection))
    print(collection + " size: " + sizeof_fmt(stats['size']))

print("--------------------")
stats = db.command("dbstats")
print("Total Steam DB Size: " + sizeof_fmt(stats['dataSize']))
# Out:
# topgames size: 159.0 MiB
# apps size: 519.3 MiB
# steamusers size: 6.4 MiB
# pricehistory size: 389.0 MiB
# --------------------
# Total Steam DB Size: 1.0 GiB
