# %%
import sys, os
from pymongo import MongoClient

from plotly.offline import init_notebook_mode, iplot
from plotly.graph_objs import *

# https://stackoverflow.com/questions/41323423/plotly-inside-jupyter-notebook-python
init_notebook_mode(connected=True) # initiate notebook for offline plot

import pandas as pd
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
sys.path.append("..")
import config # ../config.py

# run on raspberrypi3 Mongo database
#config.mongodb_ip = "192.168.1.224"
# run on Asus laptop Mongo database
#config.mongodb_ip = "192.168.1.124"
# run on Dell
config.mongodb_ip = "192.168.1.171"

client = MongoClient(host=config.mongodb_ip, port=config.mongodb_port)
db = client['steam']

# %% [markdown]
# ## Failed appids excluded from future attempts or analysis

# %%
failed_appids_df = pd.DataFrame(list(db['apps'].find({"failureCount": {"$gte":3}}, {"appid":1,"name":1,"_id":False})))
failed_appids_df
# Out:
#          appid                                               name
# 0        12630                                Legend: Hand of God
# 1        15310                    The Settlers: Heritage of Kings
# 2        19930     The Settlers: Rise of an Empire Gold Edition
# 3        23330                              The Last Remnant Demo
# 4        33220             Tom Clancy's Splinter Cell: Conviction
# 5        33910                                             Arma 2
# 6        63600                                           realMyst
# 7        81674                          Ticket to Ride Trailer EN
# 8        81675                          Ticket to Ride Trailer DE
# 9        81676                          Ticket to Ride Trailer FR
# 10      210897              Crusader Kings II: African Portraits
# 11      227240                                   Construct 2 Free
# 12      233250                             Planetary Annihilation
# 13      239570             Mark of the Ninja: Special Edition DLC
# 14      894217                                      BAIKO - 16X16
# 15           7                                       Steam Client
# 16           8                                             winui2
# 17          90                         Half-Life Dedicated Server
# 18         100      Counter-Strike: Condition Zero Deleted Scenes
# 19         205                            Source Dedicated Server
# 20         210                            Source Dedicated Server
# 21         211                                         Source SDK
# 22         215                               Source SDK Base 2006
# 23         218                               Source SDK Base 2007
# 24         260                        Counter-Strike: Source Beta
# 25         304                 Day of Defeat: Source Press Review
# 26         310                       Source 2007 Dedicated Server
# 27         364                                HL1:MP Linux client
# 28         456  Team Fortress 2 - Summer 2012 Community Bundle...
# 29         457      Team Fortress 2 - Summer 2012 Sale Bundle DLC
# ...        ...                                                ...
# 10440  1099597  Rainbow Six Siege - Pro League Rook Set Uplay ...
# 10441  1015020                                      记忆重构/Memories
# 10442   842720                           Vision Workshop Uploader
# 10443  1111260                                        WBTR Server
# 10444  1114440                         Rainbow Six Siege - test 1
# 10445  1114441                        Rainbow Six Siege -  test 2
# 10446   258320                             PATH OF EXILE: STAGING
# 10447  1102922  ROGAN: The Thief in the Castle - Hard mode ope...
# 10448  1102910                        FOCUS on YOU - 4K Wallpaper
# 10449  1102900  FOCUS on YOU - YUA's Special Costume ( Pre-Ord...
# 10450  1102901                                   FOCUS on YOU OST
# 10451  1102920  ROGAN: The Thief in the Castle - 4K Wallpaper ...
# 10452  1102921  ROGAN: The Thief in the Castle - Original Soun...
# 10453  1100020               ROGAN: the Thief of Castle Pre-order
# 10454   599350                FSX VFR NexGen C. England & N.Wales
# 10455  1088320                  Day of Dragons - Dedicated Server
# 10456   258300                                Path of Exile Alpha
# 10457  1042400      Rising Storm 2: Vietnam - Green Army Men Base
# 10458  1075820                  Green Army Men - Dedicated Server
# 10459  1120840  Rainbow Six Siege - Gold Year 4 WW Uplay Activ...
# 10460  1120844  Rainbow Six Siege - 600 R6 Credits Pack Uplay ...
# 10461  1120841  Rainbow Six Siege - Gold Year 4 RU Uplay Activ...
# 10462  1120842  Rainbow Six Siege - Ultimate Year 4 WW Uplay A...
# 10463  1120843  Rainbow Six Siege - Ultimate Year 4 RU Uplay A...
# 10464  1107881  The Bard's Tale IV: Director's Cut - Deluxe Ed...
# 10465  1107880  The Bard's Tale IV: Director's Cut - Standard ...
# 10466  1071560     ONE PIECE World Seeker Treasure Hunting Outfit
# 10467  1075980                                         NinNinDays
# 10468  1097760                                    Uh Oh Bartender
# 10469  1109970                                   Mirador Playtest
#
# [10470 rows x 2 columns]

# %%
grouped_df = db['apps'].aggregate([
{"$match":
    {"$or": [{"failureCount": {"$lt": 3}}, {"failureCount": {"$exists": False}}]}
},
{"$group":  {"_id": {"$dateToString": {"format": "%Y-%m-%d", "date": "$updated_date"}},
             "count" : { "$sum" : 1} } },
{"$sort": {"_id": 1}}
])

grouped_df = pd.DataFrame(list(grouped_df))
grouped_df.rename(columns={grouped_df.columns[0] : 'updated_date'}, inplace=True)
grouped_df
# Out:
#    updated_date  count
# 0          None      3
# 1    2019-06-19   1283
# 2    2019-06-20   3463
# 3    2019-06-21   3546
# 4    2019-06-22   3549
# 5    2019-06-23   3988
# 6    2019-06-24   3491
# 7    2019-06-25   2850
# 8    2019-06-27   2805
# 9    2019-06-28   3632
# 10   2019-06-29   2034
# 11   2019-06-30   4044
# 12   2019-07-01   3487
# 13   2019-07-02   3498
# 14   2019-07-03   3472
# 15   2019-07-04    591
# 16   2019-07-07   2487
# 17   2019-07-08   3487
# 18   2019-07-09   3283
# 19   2019-07-10   3543
# 20   2019-07-11   3486
# 21   2019-07-12   3521
# 22   2019-07-13   3544
# 23   2019-07-14   2916

# %% [markdown]
# ## Large numbers of old AppID entries means `refreshsteam.py` needs to be run.  This excludes consistently failed appids.

# %%
# https://plot.ly/python/bar-charts/

data = [Bar(
        x=grouped_df['updated_date'],
        y=grouped_df['count']
    )]

layout = Layout(
        title='AppIDs By Last Updated Date',
        xaxis=dict(
            title='Date'
        ),
        yaxis=dict(
            title='Count'
        )
    )

fig = Figure(data=data, layout=layout)

iplot(fig)
# Out:
# <div>
#
#
#             <div id="3179a856-6bc8-4fa2-a3e3-082ed2339eff" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("3179a856-6bc8-4fa2-a3e3-082ed2339eff")) {
#                     Plotly.newPlot(
#                         '3179a856-6bc8-4fa2-a3e3-082ed2339eff',
#                         [{"type": "bar", "uid": "abebb08b-b13b-4f4d-ac36-e13e4436c534", "x": [null, "2019-06-19", "2019-06-20", "2019-06-21", "2019-06-22", "2019-06-23", "2019-06-24", "2019-06-25", "2019-06-27", "2019-06-28", "2019-06-29", "2019-06-30", "2019-07-01", "2019-07-02", "2019-07-03", "2019-07-04", "2019-07-07", "2019-07-08", "2019-07-09", "2019-07-10", "2019-07-11", "2019-07-12", "2019-07-13", "2019-07-14"], "y": [3, 1283, 3463, 3546, 3549, 3988, 3491, 2850, 2805, 3632, 2034, 4044, 3487, 3498, 3472, 591, 2487, 3487, 3283, 3543, 3486, 3521, 3544, 2916]}],
#                         {"title": {"text": "AppIDs By Last Updated Date"}, "xaxis": {"title": {"text": "Date"}}, "yaxis": {"title": {"text": "Count"}}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('3179a856-6bc8-4fa2-a3e3-082ed2339eff');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
grouped_df = db['pricehistory'].aggregate([
{"$match": {}},
{"$group":  {"_id": {"$dateToString": {"format": "%Y-%m-%d", "date": "$date"}},
             "count" : { "$sum" : 1} } },
{"$sort": {"_id": 1}}
])

grouped_df = pd.DataFrame(list(grouped_df))
grouped_df.rename(columns={grouped_df.columns[0] : 'date'}, inplace=True)
grouped_df
# Out:
#            date  count
# 0    2018-09-04   8215
# 1    2018-09-05  43441
# 2    2018-09-06  37421
# 3    2018-09-07  23655
# 4    2018-09-08  37188
# 5    2018-09-10   2963
# 6    2018-09-11  45999
# 7    2018-09-12  20210
# 8    2018-09-13    269
# 9    2018-09-14  37390
# 10   2018-09-15  37650
# 11   2018-09-17  13770
# 12   2018-09-18  23910
# 13   2018-09-20  45652
# 14   2018-09-22  36531
# 15   2018-09-24   6238
# 16   2018-09-25  34293
# 17   2018-09-27  36969
# 18   2018-09-28  36974
# 19   2018-09-30   9130
# 20   2018-10-01  27797
# 21   2018-10-03  36964
# 22   2018-10-05  37018
# 23   2018-10-06  23097
# 24   2018-10-07  13902
# 25   2018-10-09  37005
# 26   2018-10-12  37128
# 27   2018-10-14  37054
# 28   2018-10-17  37148
# 29   2018-10-20  37170
# ..          ...    ...
# 220  2019-06-12   2466
# 221  2019-06-13  28036
# 222  2019-06-14   7914
# 223  2019-06-15  45604
# 224  2019-06-16   2055
# 225  2019-06-17  25946
# 226  2019-06-18  47565
# 227  2019-06-19   2357
# 228  2019-06-20  14944
# 229  2019-06-21  35675
# 230  2019-06-22   2469
# 231  2019-06-23  48734
# 232  2019-06-24   2452
# 233  2019-06-25  48003
# 234  2019-06-27   2077
# 235  2019-06-28  48369
# 236  2019-06-29   1486
# 237  2019-06-30   2798
# 238  2019-07-01  48563
# 239  2019-07-02   2494
# 240  2019-07-03   2361
# 241  2019-07-04    392
# 242  2019-07-07  52512
# 243  2019-07-08  27292
# 244  2019-07-09  25981
# 245  2019-07-10  28614
# 246  2019-07-11  27162
# 247  2019-07-12  28061
# 248  2019-07-13  26467
# 249  2019-07-14  21456
#
# [250 rows x 2 columns]

# %% [markdown]
# ## This is historical data from the `pricehistory` Mongo collection.  This is updated via the `updatepricehistory.py` script.

# %%
# https://plot.ly/python/bar-charts/

data = [Bar(
        x=grouped_df['date'],
        y=grouped_df['count']
    )]

layout = Layout(
        title='Distribution of Price History',
        xaxis=dict(
            title='Date'
        ),
        yaxis=dict(
            title='Records Count'
        )
    )

fig = Figure(data=data, layout=layout)

iplot(fig)
# Out:
# <div>
#
#
#             <div id="99514f1f-fb8a-4688-92a3-3d6897a86dd0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("99514f1f-fb8a-4688-92a3-3d6897a86dd0")) {
#                     Plotly.newPlot(
#                         '99514f1f-fb8a-4688-92a3-3d6897a86dd0',
#                         [{"type": "bar", "uid": "2c055d70-7105-4ed8-a1f4-f8a557c8cb76", "x": ["2018-09-04", "2018-09-05", "2018-09-06", "2018-09-07", "2018-09-08", "2018-09-10", "2018-09-11", "2018-09-12", "2018-09-13", "2018-09-14", "2018-09-15", "2018-09-17", "2018-09-18", "2018-09-20", "2018-09-22", "2018-09-24", "2018-09-25", "2018-09-27", "2018-09-28", "2018-09-30", "2018-10-01", "2018-10-03", "2018-10-05", "2018-10-06", "2018-10-07", "2018-10-09", "2018-10-12", "2018-10-14", "2018-10-17", "2018-10-20", "2018-10-24", "2018-10-25", "2018-10-26", "2018-10-29", "2018-10-31", "2018-11-01", "2018-11-03", "2018-11-06", "2018-11-08", "2018-11-09", "2018-11-10", "2018-11-11", "2018-11-14", "2018-11-16", "2018-11-17", "2018-11-20", "2018-11-22", "2018-11-23", "2018-11-24", "2018-11-25", "2018-11-28", "2018-11-30", "2018-12-02", "2018-12-04", "2018-12-06", "2018-12-07", "2018-12-08", "2018-12-10", "2018-12-12", "2018-12-14", "2018-12-17", "2018-12-19", "2018-12-21", "2018-12-24", "2018-12-25", "2018-12-28", "2018-12-30", "2019-01-01", "2019-01-03", "2019-01-05", "2019-01-06", "2019-01-07", "2019-01-08", "2019-01-09", "2019-01-10", "2019-01-13", "2019-01-14", "2019-01-15", "2019-01-16", "2019-01-17", "2019-01-18", "2019-01-19", "2019-01-20", "2019-01-21", "2019-01-22", "2019-01-23", "2019-01-24", "2019-01-25", "2019-01-26", "2019-01-27", "2019-01-28", "2019-01-29", "2019-01-30", "2019-01-31", "2019-02-01", "2019-02-02", "2019-02-03", "2019-02-05", "2019-02-06", "2019-02-07", "2019-02-08", "2019-02-09", "2019-02-10", "2019-02-11", "2019-02-12", "2019-02-13", "2019-02-14", "2019-02-15", "2019-02-16", "2019-02-17", "2019-02-18", "2019-02-19", "2019-02-20", "2019-02-21", "2019-02-22", "2019-02-23", "2019-02-24", "2019-02-25", "2019-02-26", "2019-02-27", "2019-02-28", "2019-03-01", "2019-03-02", "2019-03-03", "2019-03-04", "2019-03-05", "2019-03-06", "2019-03-07", "2019-03-08", "2019-03-09", "2019-03-10", "2019-03-11", "2019-03-12", "2019-03-13", "2019-03-14", "2019-03-15", "2019-03-16", "2019-03-18", "2019-03-19", "2019-03-20", "2019-03-21", "2019-03-22", "2019-03-23", "2019-03-24", "2019-03-25", "2019-03-26", "2019-03-27", "2019-03-28", "2019-03-29", "2019-03-30", "2019-03-31", "2019-04-02", "2019-04-03", "2019-04-04", "2019-04-05", "2019-04-06", "2019-04-07", "2019-04-08", "2019-04-09", "2019-04-10", "2019-04-11", "2019-04-12", "2019-04-13", "2019-04-14", "2019-04-15", "2019-04-16", "2019-04-17", "2019-04-18", "2019-04-19", "2019-04-20", "2019-04-21", "2019-04-22", "2019-04-23", "2019-04-24", "2019-04-25", "2019-04-26", "2019-04-27", "2019-04-28", "2019-04-29", "2019-04-30", "2019-05-01", "2019-05-02", "2019-05-03", "2019-05-04", "2019-05-05", "2019-05-06", "2019-05-07", "2019-05-08", "2019-05-09", "2019-05-10", "2019-05-11", "2019-05-12", "2019-05-13", "2019-05-14", "2019-05-15", "2019-05-16", "2019-05-17", "2019-05-18", "2019-05-19", "2019-05-21", "2019-05-22", "2019-05-24", "2019-05-25", "2019-05-26", "2019-05-27", "2019-05-28", "2019-05-29", "2019-05-30", "2019-05-31", "2019-06-01", "2019-06-02", "2019-06-03", "2019-06-04", "2019-06-05", "2019-06-06", "2019-06-07", "2019-06-08", "2019-06-09", "2019-06-10", "2019-06-11", "2019-06-12", "2019-06-13", "2019-06-14", "2019-06-15", "2019-06-16", "2019-06-17", "2019-06-18", "2019-06-19", "2019-06-20", "2019-06-21", "2019-06-22", "2019-06-23", "2019-06-24", "2019-06-25", "2019-06-27", "2019-06-28", "2019-06-29", "2019-06-30", "2019-07-01", "2019-07-02", "2019-07-03", "2019-07-04", "2019-07-07", "2019-07-08", "2019-07-09", "2019-07-10", "2019-07-11", "2019-07-12", "2019-07-13", "2019-07-14"], "y": [8215, 43441, 37421, 23655, 37188, 2963, 45999, 20210, 269, 37390, 37650, 13770, 23910, 45652, 36531, 6238, 34293, 36969, 36974, 9130, 27797, 36964, 37018, 23097, 13902, 37005, 37128, 37054, 37148, 37170, 37195, 22490, 14330, 37262, 3876, 33416, 37490, 37216, 36870, 19257, 18066, 37280, 37305, 37384, 37377, 37363, 37422, 27672, 9761, 37403, 37461, 37531, 37496, 37484, 37522, 24521, 13019, 37514, 3 ...
#                         {"title": {"text": "Distribution of Price History"}, "xaxis": {"title": {"text": "Date"}}, "yaxis": {"title": {"text": "Records Count"}}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('99514f1f-fb8a-4688-92a3-3d6897a86dd0');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
grouped_df = db['steamusers'].aggregate([
{"$match": {}},
{"$group":  {"_id": {"$dateToString": {"format": "%Y-%m-%d", "date": "$date"}},
             "count" : { "$sum" : 1} } },
{"$sort": {"_id": 1}}
])

grouped_df = pd.DataFrame(list(grouped_df))
grouped_df.rename(columns={grouped_df.columns[0] : 'date'}, inplace=True)
grouped_df
# Out:
#            date  count
# 0    2018-12-19    119
# 1    2018-12-20    340
# 2    2018-12-21    751
# 3    2018-12-22   1021
# 4    2018-12-23    932
# 5    2018-12-24    980
# 6    2018-12-25    938
# 7    2018-12-26    924
# 8    2018-12-27   1106
# 9    2018-12-28   1287
# 10   2018-12-29   1219
# 11   2018-12-30   1176
# 12   2018-12-31   1214
# 13   2019-01-01    943
# 14   2019-01-03    346
# 15   2019-01-05    617
# 16   2019-01-06    717
# 17   2019-01-07    134
# 18   2019-01-08    170
# 19   2019-01-09    351
# 20   2019-01-10     62
# 21   2019-01-11    267
# 22   2019-01-12    363
# 23   2019-01-13    409
# 24   2019-01-14    631
# 25   2019-01-15    626
# 26   2019-01-16    628
# 27   2019-01-17    597
# 28   2019-01-18    600
# 29   2019-01-19    627
# ..          ...    ...
# 176  2019-06-15    302
# 177  2019-06-16    325
# 178  2019-06-17    602
# 179  2019-06-18    647
# 180  2019-06-19    635
# 181  2019-06-20    618
# 182  2019-06-21    631
# 183  2019-06-22    628
# 184  2019-06-23    621
# 185  2019-06-24    537
# 186  2019-06-25    465
# 187  2019-06-26    401
# 188  2019-06-27    776
# 189  2019-06-28    853
# 190  2019-06-29    661
# 191  2019-06-30    631
# 192  2019-07-01    633
# 193  2019-07-02    635
# 194  2019-07-03    363
# 195  2019-07-04     49
# 196  2019-07-05    277
# 197  2019-07-06    893
# 198  2019-07-07   1184
# 199  2019-07-08    917
# 200  2019-07-09    906
# 201  2019-07-10    872
# 202  2019-07-11    695
# 203  2019-07-12   1021
# 204  2019-07-13   1167
# 205  2019-07-14    529
#
# [206 rows x 2 columns]

# %% [markdown]
# ## These are the number of records we have per day for the `steamusers` Mongo collection.  This is created using the `steamusers.py` script.

# %%
# https://plot.ly/python/bar-charts/

data = [Bar(
        x=grouped_df['date'],
        y=grouped_df['count']
    )]

layout = Layout(
        title='Distribution of Records Per Day for steamusers',
        xaxis=dict(
            title='Date'
        ),
        yaxis=dict(
            title='Records Count'
        )
    )

fig = Figure(data=data, layout=layout)

iplot(fig)
# Out:
# <div>
#
#
#             <div id="cadb5053-2c44-4bd4-bb1a-b0e3427e6104" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("cadb5053-2c44-4bd4-bb1a-b0e3427e6104")) {
#                     Plotly.newPlot(
#                         'cadb5053-2c44-4bd4-bb1a-b0e3427e6104',
#                         [{"type": "bar", "uid": "9b5abeaa-e097-4f34-b025-89ea9086efd0", "x": ["2018-12-19", "2018-12-20", "2018-12-21", "2018-12-22", "2018-12-23", "2018-12-24", "2018-12-25", "2018-12-26", "2018-12-27", "2018-12-28", "2018-12-29", "2018-12-30", "2018-12-31", "2019-01-01", "2019-01-03", "2019-01-05", "2019-01-06", "2019-01-07", "2019-01-08", "2019-01-09", "2019-01-10", "2019-01-11", "2019-01-12", "2019-01-13", "2019-01-14", "2019-01-15", "2019-01-16", "2019-01-17", "2019-01-18", "2019-01-19", "2019-01-20", "2019-01-21", "2019-01-22", "2019-01-23", "2019-01-24", "2019-01-25", "2019-01-26", "2019-01-27", "2019-01-28", "2019-01-29", "2019-01-30", "2019-01-31", "2019-02-01", "2019-02-02", "2019-02-03", "2019-02-04", "2019-02-05", "2019-02-06", "2019-02-07", "2019-02-08", "2019-02-09", "2019-02-10", "2019-02-11", "2019-02-12", "2019-02-13", "2019-02-14", "2019-02-15", "2019-02-16", "2019-02-17", "2019-02-18", "2019-02-19", "2019-02-20", "2019-02-21", "2019-02-22", "2019-02-23", "2019-02-24", "2019-02-25", "2019-02-26", "2019-02-27", "2019-02-28", "2019-03-01", "2019-03-02", "2019-03-03", "2019-03-04", "2019-03-05", "2019-03-06", "2019-03-07", "2019-03-08", "2019-03-09", "2019-03-10", "2019-03-11", "2019-03-12", "2019-03-13", "2019-03-14", "2019-03-15", "2019-03-16", "2019-03-17", "2019-03-18", "2019-03-19", "2019-03-20", "2019-03-21", "2019-03-22", "2019-03-23", "2019-03-24", "2019-03-25", "2019-03-26", "2019-03-27", "2019-03-28", "2019-03-29", "2019-03-30", "2019-03-31", "2019-04-01", "2019-04-02", "2019-04-03", "2019-04-04", "2019-04-05", "2019-04-06", "2019-04-07", "2019-04-08", "2019-04-09", "2019-04-10", "2019-04-11", "2019-04-12", "2019-04-13", "2019-04-14", "2019-04-15", "2019-04-16", "2019-04-17", "2019-04-18", "2019-04-19", "2019-04-20", "2019-04-21", "2019-04-22", "2019-04-23", "2019-04-24", "2019-04-25", "2019-04-26", "2019-04-27", "2019-04-28", "2019-04-29", "2019-04-30", "2019-05-01", "2019-05-02", "2019-05-03", "2019-05-04", "2019-05-05", "2019-05-06", "2019-05-07", "2019-05-08", "2019-05-09", "2019-05-10", "2019-05-11", "2019-05-12", "2019-05-13", "2019-05-14", "2019-05-15", "2019-05-16", "2019-05-17", "2019-05-18", "2019-05-19", "2019-05-20", "2019-05-21", "2019-05-22", "2019-05-23", "2019-05-24", "2019-05-25", "2019-05-26", "2019-05-27", "2019-05-28", "2019-05-29", "2019-05-30", "2019-05-31", "2019-06-01", "2019-06-02", "2019-06-03", "2019-06-04", "2019-06-05", "2019-06-06", "2019-06-07", "2019-06-08", "2019-06-09", "2019-06-10", "2019-06-11", "2019-06-12", "2019-06-13", "2019-06-14", "2019-06-15", "2019-06-16", "2019-06-17", "2019-06-18", "2019-06-19", "2019-06-20", "2019-06-21", "2019-06-22", "2019-06-23", "2019-06-24", "2019-06-25", "2019-06-26", "2019-06-27", "2019-06-28", "2019-06-29", "2019-06-30", "2019-07-01", "2019-07-02", "2019-07-03", "2019-07-04", "2019-07-05", "2019-07-06", "2019-07-07", "2019-07-08", "2019-07-09", "2019-07-10", "2019-07-11", "2019-07-12", "2019-07-13", "2019-07-14"], "y": [119, 340, 751, 1021, 932, 980, 938, 924, 1106, 1287, 1219, 1176, 1214, 943, 346, 617, 717, 134, 170, 351, 62, 267, 363, 409, 631, 626, 628, 597, 600, 627, 629, 630, 628, 629, 754, 755, 622, 623, 621, 621, 626, 629, 628, 520, 348, 452, 625, 620, 622, 622, 625, 629, 624, 631, 627, 626, 624, 600, 607, 630, 633, 642, 635, 628, 626, 563, 506, 563, 622, 604, 640, 643, 630, 628, 631, 629, 630, 641, 642, 701, 728, 620, 622, 625, 627, 338, 297, 586, 625, 567, 565, 625, 628, 627, 470, 467, 460, 427, 593, 323, 13, 295, 619, 871, 868, 716, 724, 640, 622, 620, 623, 625, 501, 500, 624, 630, 627, 628, 615, 513, 778, 874, 627, 624, 637, 636, 628, 578, 552, 608, 863, 848, 459, 465, 631, 623, 630, 711, 709, 647, 361, 317, 572, 603, 640, 836, 846, 645, 344, 282, 568, 351, 327, 620, 640, 629, 575, 445, 497, 629, 632, 397, 353, 588, 604, 607, 631, 544, 543, 629, 640, 877, 883, 387, 350, 550, 302, 325, 602, 647, 635, 618, 631, 628, 621, 537, 465, 401, 776, 853, 661, 631, 633, 635, 363, 49, 277, 893, 1184, 917, 906, 872, 6 ...
#                         {"title": {"text": "Distribution of Records Per Day for steamusers"}, "xaxis": {"title": {"text": "Date"}}, "yaxis": {"title": {"text": "Records Count"}}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('cadb5053-2c44-4bd4-bb1a-b0e3427e6104');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
grouped_df = db['topgames'].aggregate([
{"$match": {}},
{"$group":  {"_id": {"$dateToString": {"format": "%Y-%m-%d", "date": "$date"}},
             "count" : { "$sum" : 1} } },
{"$sort": {"_id": 1}}
])

grouped_df = pd.DataFrame(list(grouped_df))
grouped_df.rename(columns={grouped_df.columns[0] : 'date'}, inplace=True)
grouped_df
# Out:
#            date  count
# 0    2019-01-08    300
# 1    2019-01-09   2300
# 2    2019-01-10    100
# 3    2019-01-13   4000
# 4    2019-01-14   9000
# 5    2019-01-15   8400
# 6    2019-01-16   9200
# 7    2019-01-17   8500
# 8    2019-01-18   9100
# 9    2019-01-19   5200
# 10   2019-01-20   9200
# 11   2019-01-21   8500
# 12   2019-01-22   9000
# 13   2019-01-23   8400
# 14   2019-01-24   9100
# 15   2019-01-25   8600
# 16   2019-01-26   8700
# 17   2019-01-27   8600
# 18   2019-01-28   8200
# 19   2019-01-29   8700
# 20   2019-01-30   8100
# 21   2019-01-31   8600
# 22   2019-02-01   8200
# 23   2019-02-02   8600
# 24   2019-02-03   7000
# 25   2019-02-05   4100
# 26   2019-02-06   8700
# 27   2019-02-07   8200
# 28   2019-02-08   8500
# 29   2019-02-09   8200
# ..          ...    ...
# 149  2019-06-12   8400
# 150  2019-06-13   8000
# 151  2019-06-14   1900
# 152  2019-06-15   4300
# 153  2019-06-16   4700
# 154  2019-06-17   6700
# 155  2019-06-18   8100
# 156  2019-06-19   8700
# 157  2019-06-20   8400
# 158  2019-06-21   8300
# 159  2019-06-22   8300
# 160  2019-06-23   8000
# 161  2019-06-24   8700
# 162  2019-06-25   6800
# 163  2019-06-27   7400
# 164  2019-06-28   8700
# 165  2019-06-29   6700
# 166  2019-06-30   8400
# 167  2019-07-01   8000
# 168  2019-07-02   8500
# 169  2019-07-03   8000
# 170  2019-07-04   1800
# 171  2019-07-07   7000
# 172  2019-07-08   8000
# 173  2019-07-09   8100
# 174  2019-07-10   8700
# 175  2019-07-11   8700
# 176  2019-07-12   8700
# 177  2019-07-13   8800
# 178  2019-07-14   7500
#
# [179 rows x 2 columns]

# %% [markdown]
# ## These are the number of entries we have per day for the `topgames` Mongo collection.  Each query returns the current top 100 games being played.  This is run every 15 minutes.

# %%
# https://plot.ly/python/bar-charts/

data = [Bar(
        x=grouped_df['date'],
        y=grouped_df['count']
    )]

layout = Layout(
        title='Distribution of Records Per Day for topgames',
        xaxis=dict(
            title='Date'
        ),
        yaxis=dict(
            title='Records Count'
        )
    )

fig = Figure(data=data, layout=layout)

iplot(fig)
# Out:
# <div>
#
#
#             <div id="2086945d-ac7e-4183-9ddc-6a9cd1eff352" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("2086945d-ac7e-4183-9ddc-6a9cd1eff352")) {
#                     Plotly.newPlot(
#                         '2086945d-ac7e-4183-9ddc-6a9cd1eff352',
#                         [{"type": "bar", "uid": "38bb63ed-3730-4fa5-b278-497a320a0844", "x": ["2019-01-08", "2019-01-09", "2019-01-10", "2019-01-13", "2019-01-14", "2019-01-15", "2019-01-16", "2019-01-17", "2019-01-18", "2019-01-19", "2019-01-20", "2019-01-21", "2019-01-22", "2019-01-23", "2019-01-24", "2019-01-25", "2019-01-26", "2019-01-27", "2019-01-28", "2019-01-29", "2019-01-30", "2019-01-31", "2019-02-01", "2019-02-02", "2019-02-03", "2019-02-05", "2019-02-06", "2019-02-07", "2019-02-08", "2019-02-09", "2019-02-10", "2019-02-11", "2019-02-12", "2019-02-13", "2019-02-14", "2019-02-15", "2019-02-16", "2019-02-17", "2019-02-18", "2019-02-19", "2019-02-20", "2019-02-21", "2019-02-22", "2019-02-23", "2019-02-24", "2019-02-25", "2019-02-26", "2019-02-27", "2019-02-28", "2019-03-01", "2019-03-02", "2019-03-03", "2019-03-04", "2019-03-05", "2019-03-06", "2019-03-07", "2019-03-08", "2019-03-09", "2019-03-10", "2019-03-11", "2019-03-12", "2019-03-13", "2019-03-14", "2019-03-15", "2019-03-16", "2019-03-17", "2019-03-18", "2019-03-19", "2019-03-20", "2019-03-21", "2019-03-22", "2019-03-23", "2019-03-24", "2019-03-25", "2019-03-26", "2019-03-27", "2019-03-28", "2019-03-29", "2019-03-30", "2019-03-31", "2019-04-02", "2019-04-03", "2019-04-04", "2019-04-05", "2019-04-06", "2019-04-07", "2019-04-08", "2019-04-09", "2019-04-10", "2019-04-11", "2019-04-12", "2019-04-13", "2019-04-14", "2019-04-15", "2019-04-16", "2019-04-17", "2019-04-18", "2019-04-19", "2019-04-20", "2019-04-21", "2019-04-22", "2019-04-23", "2019-04-24", "2019-04-25", "2019-04-26", "2019-04-27", "2019-04-28", "2019-04-29", "2019-04-30", "2019-05-01", "2019-05-02", "2019-05-03", "2019-05-04", "2019-05-05", "2019-05-06", "2019-05-07", "2019-05-08", "2019-05-09", "2019-05-10", "2019-05-11", "2019-05-12", "2019-05-13", "2019-05-14", "2019-05-15", "2019-05-16", "2019-05-17", "2019-05-18", "2019-05-19", "2019-05-21", "2019-05-22", "2019-05-24", "2019-05-25", "2019-05-26", "2019-05-27", "2019-05-28", "2019-05-29", "2019-05-30", "2019-05-31", "2019-06-01", "2019-06-02", "2019-06-03", "2019-06-04", "2019-06-05", "2019-06-06", "2019-06-07", "2019-06-08", "2019-06-09", "2019-06-10", "2019-06-11", "2019-06-12", "2019-06-13", "2019-06-14", "2019-06-15", "2019-06-16", "2019-06-17", "2019-06-18", "2019-06-19", "2019-06-20", "2019-06-21", "2019-06-22", "2019-06-23", "2019-06-24", "2019-06-25", "2019-06-27", "2019-06-28", "2019-06-29", "2019-06-30", "2019-07-01", "2019-07-02", "2019-07-03", "2019-07-04", "2019-07-07", "2019-07-08", "2019-07-09", "2019-07-10", "2019-07-11", "2019-07-12", "2019-07-13", "2019-07-14"], "y": [300, 2300, 100, 4000, 9000, 8400, 9200, 8500, 9100, 5200, 9200, 8500, 9000, 8400, 9100, 8600, 8700, 8600, 8200, 8700, 8100, 8600, 8200, 8600, 7000, 4100, 8700, 8200, 8500, 8200, 8600, 8300, 8600, 8100, 8700, 8100, 8700, 7600, 7400, 8700, 8100, 8700, 8100, 8500, 8200, 8600, 8600, 8600, 8200, 8700, 8100, 8600, 8100, 8700, 8200, 8600, 8100, 8600, 8100, 8700, 8600, 8600, 8000, 8600, 8000, 600, 7200, 8700, 8100, 6400, 7100, 8300, 8200, 7900, 1800, 4600, 8700, 700, 8400, 7000, 8300, 8700, 7500, 8600, 8600, 5000, 8600, 8200, 8600, 8100, 8700, 8000, 8500, 8100, 8700, 8200, 8200, 8400, 3700, 8000, 8600, 8600, 7800, 8600, 7200, 7000, 8100, 2300, 7000, 6400, 5600, 4000, 3400, 8200, 8000, 7800, 7100, 7000, 4400, 6800, 7200, 3800, 5500, 8500, 7600, 8200, 8200, 5800, 5900, 4400, 8700, 8700, 8100, 8700, 8300, 8700, 8100, 8600, 4500, 7800, 8600, 4200, 8400, 8300, 3800, 6900, 7000, 4400, 8200, 8400, 8000, 1900, 4300, 4700, 6700, 8100, 8700, 8400, 8300, 8300, 8000, 8700, 6800, 7400, 8700, 6700, 8400, 8000, 8500, 8000, 1800, 7000, 8000, 8100, 8700, 8700, 8700, 8800, 7500]}],
#                         {"title": {"text": "Distribution of Records Per Day for topgames"}, "xaxis": {"title": {"text": "Date"}}, "yaxis": {"title": {"text": "Records Count"}}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('2086945d-ac7e-4183-9ddc-6a9cd1eff352');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
steam_grouped_df = db['opencritic'].aggregate([
{"$match": {"steamId": {"$exists": True}}},
{"$group":  {"_id": {"$dateToString": {"format": "%Y-%m-%d", "date": "$date"}},
             "count" : { "$sum" : 1} } },
{"$sort": {"_id": 1}}
])

steam_grouped_df = pd.DataFrame(list(steam_grouped_df))
steam_grouped_df.rename(columns={steam_grouped_df.columns[0] : 'date'}, inplace=True)

nonsteam_grouped_df = db['opencritic'].aggregate([
{"$match": {"steamId": {"$exists": False}}},
{"$group":  {"_id": {"$dateToString": {"format": "%Y-%m-%d", "date": "$date"}},
             "count" : { "$sum" : 1} } },
{"$sort": {"_id": 1}}
])

nonsteam_grouped_df = pd.DataFrame(list(nonsteam_grouped_df))
nonsteam_grouped_df.rename(columns={nonsteam_grouped_df.columns[0] : 'date'}, inplace=True)

print(steam_grouped_df)
print(nonsteam_grouped_df)
# Out:
#          date  count
# 0  2019-07-14     25
#          date  count
# 0  2019-07-14   1229

# %% [markdown]
# ## This is the breakdown of OpenCritic data we have by last accessed/updated date.

# %%
# https://plot.ly/python/bar-charts/#stacked-bar-chart

steamTrace = Bar(
    x=steam_grouped_df['date'],
    y=steam_grouped_df['count'],
    name='Games w/steamId'
)
nonSteamTrace = Bar(
    x=nonsteam_grouped_df['date'],
    y=nonsteam_grouped_df['count'],
    name='Games without steamId'
)

data = [steamTrace, nonSteamTrace]

layout = Layout(
        title='Distribution of OpenCritic Records Per Day Grouped By steamId',
        xaxis=dict(
            title='Date'
        ),
        yaxis=dict(
            title='Records Count'
        ),
        barmode='stack'
    )

fig = Figure(data=data, layout=layout)

iplot(fig)
# Out:
# <div>
#
#
#             <div id="44e2a1c7-d4f5-4512-90bb-8936e766226d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("44e2a1c7-d4f5-4512-90bb-8936e766226d")) {
#                     Plotly.newPlot(
#                         '44e2a1c7-d4f5-4512-90bb-8936e766226d',
#                         [{"name": "Games w/steamId", "type": "bar", "uid": "d596b216-dbe0-4234-91a7-748cfef26285", "x": ["2019-07-14"], "y": [25]}, {"name": "Games without steamId", "type": "bar", "uid": "6279aca6-35c7-4138-ab0e-b2598c7b4ff3", "x": ["2019-07-14"], "y": [1229]}],
#                         {"barmode": "stack", "title": {"text": "Distribution of OpenCritic Records Per Day Grouped By steamId"}, "xaxis": {"title": {"text": "Date"}}, "yaxis": {"title": {"text": "Records Count"}}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('44e2a1c7-d4f5-4512-90bb-8936e766226d');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# ## This is counts of Twitch records by day grouped by a tie to Steam

# %%
steam_grouped_df = db['twitchhistorical'].aggregate([
{"$match": {"steamId": {"$exists": True}}},
{"$group":  {"_id": {"$dateToString": {"format": "%Y-%m-%d", "date": "$date"}},
             "count" : { "$sum" : 1} } },
{"$sort": {"_id": 1}}
])

steam_grouped_df = pd.DataFrame(list(steam_grouped_df))
steam_grouped_df.rename(columns={steam_grouped_df.columns[0] : 'date'}, inplace=True)

nonsteam_grouped_df = db['twitchhistorical'].aggregate([
{"$match": {"steamId": {"$exists": False}}},
{"$group":  {"_id": {"$dateToString": {"format": "%Y-%m-%d", "date": "$date"}},
             "count" : { "$sum" : 1} } },
{"$sort": {"_id": 1}}
])

nonsteam_grouped_df = pd.DataFrame(list(nonsteam_grouped_df))
nonsteam_grouped_df.rename(columns={nonsteam_grouped_df.columns[0] : 'date'}, inplace=True)

# https://plot.ly/python/bar-charts/#stacked-bar-chart

steamTrace = Bar(
    x=steam_grouped_df['date'],
    y=steam_grouped_df['count'],
    name='Games w/steamId'
)
nonSteamTrace = Bar(
    x=nonsteam_grouped_df['date'],
    y=nonsteam_grouped_df['count'],
    name='Games without steamId'
)

data = [steamTrace, nonSteamTrace]

layout = Layout(
        title='Distribution of Twitch Records Per Day Grouped By steamId',
        xaxis=dict(
            title='Date'
        ),
        yaxis=dict(
            title='Records Count'
        ),
        barmode='stack'
    )

fig = Figure(data=data, layout=layout)

iplot(fig)
# Out:
# <div>
#
#
#             <div id="8997488b-3932-4b4d-9fd5-fe6f2c2da57c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("8997488b-3932-4b4d-9fd5-fe6f2c2da57c")) {
#                     Plotly.newPlot(
#                         '8997488b-3932-4b4d-9fd5-fe6f2c2da57c',
#                         [{"name": "Games w/steamId", "type": "bar", "uid": "e79a8525-2083-4c5a-8b50-a80e90b21fec", "x": ["2019-07-14"], "y": [21145]}, {"name": "Games without steamId", "type": "bar", "uid": "cddaef2c-4670-4ba8-bd3b-eca17ec51fb4", "x": ["2019-07-14"], "y": [28597]}],
#                         {"barmode": "stack", "title": {"text": "Distribution of Twitch Records Per Day Grouped By steamId"}, "xaxis": {"title": {"text": "Date"}}, "yaxis": {"title": {"text": "Records Count"}}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('8997488b-3932-4b4d-9fd5-fe6f2c2da57c');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# ## Storage and disk usage information

# %%
# https://stackoverflow.com/questions/1094841/reusable-library-to-get-human-readable-version-of-file-size
def sizeof_fmt(num, suffix='B'):
    for unit in ['','Ki','Mi','Gi','Ti','Pi','Ei','Zi']:
        if abs(num) < 1024.0:
            return "%3.1f %s%s" % (num, unit, suffix)
        num /= 1024.0
    return "%.1f %s%s" % (num, 'Yi', suffix)

for collection in db.list_collection_names():
    stats = db.command("collstats", str(collection))
    print(collection + " size: " + sizeof_fmt(stats['size']))

print("--------------------")
stats = db.command("dbstats")
print("Total Steam DB Size: " + sizeof_fmt(stats['dataSize']))
# Out:
# twitchhistorical size: 19.8 MiB
# apps size: 544.1 MiB
# pricehistory size: 504.5 MiB
# topgames size: 235.7 MiB
# steamusers size: 9.3 MiB
# opencritic size: 698.4 KiB
# --------------------
# Total Steam DB Size: 1.3 GiB
