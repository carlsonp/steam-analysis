# %%
import sys, os
from pymongo import MongoClient

from plotly.offline import init_notebook_mode, iplot
from plotly.graph_objs import *

# https://stackoverflow.com/questions/41323423/plotly-inside-jupyter-notebook-python
init_notebook_mode(connected=True) # initiate notebook for offline plot

import pandas as pd

from dotenv import load_dotenv
# Out:
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.5.0.min"</script>

# %%
load_dotenv("../.env")
# Out:
# True

# %%
sys.path.append("../src/")
import common # ../src/common.py

uri = f"mongodb://root:{os.environ['MONGODB_ROOT_PASSWORD']}@{os.environ['MONGODB_IP']}:{os.environ['MONGODB_PORT']}/"

client = MongoClient(uri)
db = client['steam']

# %% [markdown]
# ## Failed appids excluded from future attempts or analysis

# %%
failed_appids_df = pd.DataFrame(list(db['apps'].find({"failureCount": {"$gte":3}}, {"appid":1,"name":1,"_id":False})))
failed_appids_df
# Out:
#                                     name    appid
# 0                           Zombie Movie      900
# 1      Day of Defeat: Prelude to Victory      901
# 2               Dangerous Waters Trailer      902
# 3                    Half-Life 2 Trailer      904
# 4       Half-Life 2: Episode One Trailer      905
# ...                                  ...      ...
# 39770        Myth of Empires: Завоевания  4348430
# 39771                              口袋训练师  4390580
# 39772     RagnarokX: Следующее поколение  4483700
# 39773                               VEAT  4517110
# 39774                              超词元同居  4576170
#
# [39775 rows x 2 columns]

# %%
grouped_df = db['apps'].aggregate([
{"$match":
    {"$or": [{"failureCount": {"$lt": 3}}, {"failureCount": {"$exists": False}}]}
},
{"$group":  {"_id": {"$dateToString": {"format": "%Y-%m-%d", "date": "$updated_date"}},
             "count" : { "$sum" : 1} } },
{"$sort": {"_id": 1}}
])

grouped_df = pd.DataFrame(list(grouped_df))
grouped_df.rename(columns={grouped_df.columns[0] : 'updated_date'}, inplace=True)
grouped_df
# Out:
#    updated_date  count
# 0    2026-03-15   1600
# 1    2026-03-16   3464
# 2    2026-03-17   3477
# 3    2026-03-18   3963
# 4    2026-03-19   3466
# ..          ...    ...
# 73   2026-05-27   3698
# 74   2026-05-28   3849
# 75   2026-05-29   3697
# 76   2026-05-30   4167
# 77   2026-05-31     11
#
# [78 rows x 2 columns]

# %% [markdown]
# ## Large numbers of old AppID entries means `refreshsteam.py` needs to be run.  This excludes consistently failed appids.

# %%
# https://plot.ly/python/bar-charts/

data = [Bar(
        x=grouped_df['updated_date'],
        y=grouped_df['count']
    )]

layout = Layout(
        title='AppIDs By Last Updated Date',
        xaxis=dict(
            title='Date'
        ),
        yaxis=dict(
            title='Count'
        )
    )

fig = Figure(data=data, layout=layout)

iplot(fig)

# %%
grouped_df = db['pricehistory'].aggregate([
{"$match": {}},
{"$group":  {"_id": {"$dateToString": {"format": "%Y-%m-%d", "date": "$date"}},
             "count" : { "$sum" : 1} } },
{"$sort": {"_id": 1}}
])

grouped_df = pd.DataFrame(list(grouped_df))
grouped_df.rename(columns={grouped_df.columns[0] : 'date'}, inplace=True)
grouped_df
# Out:
#             date  count
# 0     2018-09-04   8215
# 1     2018-09-05  43441
# 2     2018-09-06  37421
# 3     2018-09-07  23655
# 4     2018-09-08  37188
# ...          ...    ...
# 2597  2026-05-27  25952
# 2598  2026-05-28  28318
# 2599  2026-05-29  28029
# 2600  2026-05-30  28410
# 2601  2026-05-31   1192
#
# [2602 rows x 2 columns]

# %% [markdown]
# ## This is historical data from the `pricehistory` Mongo collection.  This is updated via the `updatepricehistory.py` script.

# %%
# https://plot.ly/python/bar-charts/

data = [Bar(
        x=grouped_df['date'],
        y=grouped_df['count']
    )]

layout = Layout(
        title='Distribution of Price History',
        xaxis=dict(
            title='Date'
        ),
        yaxis=dict(
            title='Records Count'
        )
    )

fig = Figure(data=data, layout=layout)

iplot(fig)

# %%
grouped_df = db['steamusers'].aggregate([
{"$match": {}},
{"$group":  {"_id": {"$dateToString": {"format": "%Y-%m-%d", "date": "$date"}},
             "count" : { "$sum" : 1} } },
{"$sort": {"_id": 1}}
])

grouped_df = pd.DataFrame(list(grouped_df))
grouped_df.rename(columns={grouped_df.columns[0] : 'date'}, inplace=True)
grouped_df
# Out:
#             date  count
# 0     2018-12-19    119
# 1     2018-12-20    340
# 2     2018-12-21    751
# 3     2018-12-22   1021
# 4     2018-12-23    932
# ...          ...    ...
# 2605  2026-05-26    880
# 2606  2026-05-27    642
# 2607  2026-05-28    625
# 2608  2026-05-29    582
# 2609  2026-05-30    271
#
# [2610 rows x 2 columns]

# %% [markdown]
# ## These are the number of records we have per day for the `steamusers` Mongo collection.  This is created using the `steamusers.py` script.

# %%
# https://plot.ly/python/bar-charts/

data = [Bar(
        x=grouped_df['date'],
        y=grouped_df['count']
    )]

layout = Layout(
        title='Distribution of Records Per Day for steamusers',
        xaxis=dict(
            title='Date'
        ),
        yaxis=dict(
            title='Records Count'
        )
    )

fig = Figure(data=data, layout=layout)

iplot(fig)

# %%
grouped_df = db['topgames'].aggregate([
{"$match": {}},
{"$group":  {"_id": {"$dateToString": {"format": "%Y-%m-%d", "date": "$date"}},
             "count" : { "$sum" : 1} } },
{"$sort": {"_id": 1}}
])

grouped_df = pd.DataFrame(list(grouped_df))
grouped_df.rename(columns={grouped_df.columns[0] : 'date'}, inplace=True)
grouped_df
# Out:
#             date  count
# 0     2019-01-08    300
# 1     2019-01-09   2300
# 2     2019-01-10    100
# 3     2019-01-13   4000
# 4     2019-01-14   9000
# ...          ...    ...
# 1310  2026-05-27   7000
# 1311  2026-05-28   7400
# 1312  2026-05-29   7400
# 1313  2026-05-30   7300
# 1314  2026-05-31    400
#
# [1315 rows x 2 columns]

# %% [markdown]
# ## These are the number of entries we have per day for the `topgames` Mongo collection.  Each query returns the current top 100 games being played.  This is run every 15 minutes.

# %%
# https://plot.ly/python/bar-charts/

data = [Bar(
        x=grouped_df['date'],
        y=grouped_df['count']
    )]

layout = Layout(
        title='Distribution of Records Per Day for topgames',
        xaxis=dict(
            title='Date'
        ),
        yaxis=dict(
            title='Records Count'
        )
    )

fig = Figure(data=data, layout=layout)

iplot(fig)

# %%
grouped_df = db['apps'].aggregate([
{"$match": {"type": {"$in": ["game", "dlc"]}}},
{"$group":  {"_id": {"$dateToString": {"format": "%Y-%m-%d", "date": "$reviews.last_updated"}},
             "count" : { "$sum" : 1} } },
{"$sort": {"_id": 1}}
])

grouped_df = pd.DataFrame(list(grouped_df))
grouped_df.rename(columns={grouped_df.columns[0] : 'date'}, inplace=True)
grouped_df
# Out:
#             date  count
# 0            NaN  87748
# 1     2021-03-07      4
# 2     2021-03-08      3
# 3     2021-03-15      1
# 4     2021-03-20      1
# ...          ...    ...
# 1031  2026-05-27   1800
# 1032  2026-05-28   1850
# 1033  2026-05-29   1850
# 1034  2026-05-30   1800
# 1035  2026-05-31    100
#
# [1036 rows x 2 columns]

# %% [markdown]
# ## These are the number of Steam games where we have review information from Steam and when they were last updated

# %%
# https://plot.ly/python/bar-charts/

data = [Bar(
        x=grouped_df['date'],
        y=grouped_df['count']
    )]

layout = Layout(
        title='Distribution of Steam game reviews per day',
        xaxis=dict(
            title='Date'
        ),
        yaxis=dict(
            title='Records Count'
        )
    )

fig = Figure(data=data, layout=layout)

iplot(fig)

# %%
steam_grouped_df = db['opencritic'].aggregate([
{"$match": {"steamId": {"$exists": True, "$ne": None}}},
{"$group":  {"_id": {"$dateToString": {"format": "%Y-%m-%d", "date": "$date"}},
             "count" : { "$sum" : 1} } },
{"$sort": {"_id": 1}}
])

steam_grouped_df = pd.DataFrame(list(steam_grouped_df))
steam_grouped_df.rename(columns={steam_grouped_df.columns[0] : 'date'}, inplace=True)

nonsteam_grouped_df = db['opencritic'].aggregate([
{"$match": {"$or": [{"steamId": {"$exists": False}}, {"steamId": None}]}},
{"$group":  {"_id": {"$dateToString": {"format": "%Y-%m-%d", "date": "$date"}},
             "count" : { "$sum" : 1} } },
{"$sort": {"_id": 1}}
])

nonsteam_grouped_df = pd.DataFrame(list(nonsteam_grouped_df))
nonsteam_grouped_df.rename(columns={nonsteam_grouped_df.columns[0] : 'date'}, inplace=True)

print(steam_grouped_df)
print(nonsteam_grouped_df)
# Out:
#           date  count
# 0   2022-01-30    180
# 1   2022-01-31    216
# 2   2022-02-01    219
# 3   2022-02-02    210
# 4   2022-02-03    234
# 5   2022-02-04    148
# 6   2022-02-05    178
# 7   2022-02-06    247
# 8   2022-02-07    230
# 9   2022-02-08    228
# 10  2022-02-09    248
# 11  2022-02-10    219
# 12  2022-02-11    200
# 13  2022-02-12    239
# 14  2022-02-13     66
# 15  2022-02-14    214
# 16  2022-02-15    145
# 17  2022-02-16    207
# 18  2022-02-17    239
# 19  2022-02-18    221
# 20  2022-02-19    124
# 21  2022-02-22    197
# 22  2022-02-23    198
# 23  2022-02-24    203
#           date  count
# 0   2022-01-30    224
# 1   2022-01-31    240
# 2   2022-02-01    309
# 3   2022-02-02    270
# 4   2022-02-03    294
# 5   2022-02-04    308
# 6   2022-02-05    350
# 7   2022-02-06    281
# 8   2022-02-07    298
# 9   2022-02-08    300
# 10  2022-02-09    280
# 11  2022-02-10    309
# 12  2022-02-11    328
# 13  2022-02-12    289
# 14  2022-02-13    102
# 15  2022-02-14    290
# 16  2022-02-15    237
# 17  2022-02-16    321
# 18  2022-02-17    289
# 19  2022-02-18    288
# 20  2022-02-19    221
# 21  2022-02-22    286
# 22  2022-02-23    262
# 23  2022-02-24    280

# %% [markdown]
# ## This is the breakdown of OpenCritic data we have by last accessed/updated date.

# %%
# https://plot.ly/python/bar-charts/#stacked-bar-chart

steamTrace = Bar(
    x=steam_grouped_df['date'],
    y=steam_grouped_df['count'],
    name='Games w/steamId'
)
nonSteamTrace = Bar(
    x=nonsteam_grouped_df['date'],
    y=nonsteam_grouped_df['count'],
    name='Games without steamId'
)

data = [steamTrace, nonSteamTrace]

layout = Layout(
        title='Distribution of OpenCritic Records Per Day Grouped By steamId',
        xaxis=dict(
            title='Date'
        ),
        yaxis=dict(
            title='Records Count'
        ),
        barmode='stack'
    )

fig = Figure(data=data, layout=layout)

iplot(fig)

# %% [markdown]
# ## This is counts of Twitch records by day grouped by a tie to Steam

# %%
steam_grouped_df = db['twitchhistorical'].aggregate([
{"$match": {"steamId": {"$exists": True}}},
{"$group":  {"_id": {"$dateToString": {"format": "%Y-%m-%d", "date": "$date"}},
             "count" : { "$sum" : 1} } },
{"$sort": {"_id": 1}}
])

steam_grouped_df = pd.DataFrame(list(steam_grouped_df))
steam_grouped_df.rename(columns={steam_grouped_df.columns[0] : 'date'}, inplace=True)

nonsteam_grouped_df = db['twitchhistorical'].aggregate([
{"$match": {"steamId": {"$exists": False}}},
{"$group":  {"_id": {"$dateToString": {"format": "%Y-%m-%d", "date": "$date"}},
             "count" : { "$sum" : 1} } },
{"$sort": {"_id": 1}}
])

nonsteam_grouped_df = pd.DataFrame(list(nonsteam_grouped_df))
nonsteam_grouped_df.rename(columns={nonsteam_grouped_df.columns[0] : 'date'}, inplace=True)

# https://plot.ly/python/bar-charts/#stacked-bar-chart

steamTrace = Bar(
    x=steam_grouped_df['date'],
    y=steam_grouped_df['count'],
    name='Games w/steamId'
)
nonSteamTrace = Bar(
    x=nonsteam_grouped_df['date'],
    y=nonsteam_grouped_df['count'],
    name='Games without steamId'
)

data = [steamTrace, nonSteamTrace]

layout = Layout(
        title='Distribution of Twitch Records Per Day Grouped By steamId',
        xaxis=dict(
            title='Date'
        ),
        yaxis=dict(
            title='Records Count'
        ),
        barmode='stack'
    )

fig = Figure(data=data, layout=layout)

iplot(fig)

# %% [markdown]
# ## IsThereAnyDeal historical data

# %%
grouped_df = db['isthereanydealhistory'].aggregate([
{"$match": {}},
{"$group":  {"_id": {"$dateToString": {"format": "%Y-%m-%d", "date": "$date"}},
             "count" : { "$sum" : 1} } },
{"$sort": {"_id": 1}}
])

grouped_df = pd.DataFrame(list(grouped_df))
grouped_df.rename(columns={grouped_df.columns[0] : 'date'}, inplace=True)
grouped_df
# Out:
#          date  count
# 0  2026-05-25   2381
# 1  2026-05-26  14400
# 2  2026-05-27  14000
# 3  2026-05-28  14800
# 4  2026-05-29  14800
# 5  2026-05-30  14399
# 6  2026-05-31    855

# %%
# https://plot.ly/python/bar-charts/

data = [Bar(
        x=grouped_df['date'],
        y=grouped_df['count']
    )]

layout = Layout(
        title='Distribution of historical IsThereAnyDeal data per day',
        xaxis=dict(
            title='Date'
        ),
        yaxis=dict(
            title='Records Count'
        )
    )

fig = Figure(data=data, layout=layout)

iplot(fig)

# %% [markdown]
# ## Comparison of coverage between our unique list of historical records from isthereanydeal compared to the unique list of appids from Steam

# %%
pipeline = [
    {"$match": {"type": {
                "$in": ["game", "dlc"]
            }
       }
    },
    {
        "$group": {
            "_id": "$appid"
        }
    },
    {
        "$project": {
            "_id": 0,
            "appid": "$_id"
        }
    }
]
steam_apps_length = len(list(db["apps"].aggregate(pipeline, allowDiskUse=True)))

pipeline = [
    {"$match": {"type": {
                "$in": ["game", "dlc"]
            }
       }
    },
    {
        "$group": {
            "_id": "$appid"
        }
    },
    {
        "$project": {
            "_id": 0,
            "appid": "$_id"
        }
    }
]
isthereanydealhistory_length = len(list(db["isthereanydealhistory"].aggregate(pipeline, allowDiskUse=True)))

print(f"Percentage of coverage from isthereanydeal history collection: {round((isthereanydealhistory_length / steam_apps_length)*100, 3)}%")
# Out:
# Percentage of coverage from isthereanydeal history collection: 4.903%

# %%
grouped_df = db['bandwidth'].aggregate([
{"$match": {}},
{"$group":  {"_id": {"$dateToString": {"format": "%Y-%m-%d", "date": "$date"}},
             "bytes" : { "$sum" : "$bytes"} } },
{"$sort": {"_id": 1}}
])

grouped_df = pd.DataFrame(list(grouped_df))
grouped_df.rename(columns={grouped_df.columns[0] : 'date'}, inplace=True)
grouped_df
# Out:
#             date     bytes
# 0     2020-08-24  47308192
# 1     2020-08-25  60355637
# 2     2020-08-26  61575373
# 3     2020-08-27  62138445
# 4     2020-08-28  65542520
# ...          ...       ...
# 1984  2026-05-27  85549068
# 1985  2026-05-28  95239161
# 1986  2026-05-29  90569208
# 1987  2026-05-30  88434597
# 1988  2026-05-31   7092728
#
# [1989 rows x 2 columns]

# %% [markdown]
# ## Bandwidth used

# %%
# https://plot.ly/python/bar-charts/

data = [Bar(
        x=grouped_df['date'],
        y=grouped_df['bytes']
    )]

layout = Layout(
        title='Data downloaded per day',
        xaxis=dict(
            title='Date'
        ),
        yaxis=dict(
            title='Bytes'
        )
    )

fig = Figure(data=data, layout=layout)

iplot(fig)

# %% [markdown]
# ## Storage and disk usage information

# %%
for collection in db.list_collection_names():
    stats = db.command("collstats", str(collection))
    print(collection + " size: " + common.sizeof_fmt(stats['size']))

print("--------------------")
stats = db.command("dbstats")
print("Total Database Size: " + common.sizeof_fmt(stats['dataSize']))
# Out:
# apps size: 3.7 GiB
# twitchhistorical size: 7.6 GiB
# pricehistory size: 5.9 GiB
# topgames size: 1.9 GiB
# isthereanydealhistory size: 183.6 MiB
# opencritic size: 200.8 MiB
# bandwidth size: 17.9 MiB
# isthereanydeal size: 14.0 MiB
# steamusers size: 121.7 MiB
# --------------------
# Total Database Size: 19.5 GiB

# %% [markdown]
# ## Check index size across collections

# %%
total_index = 0
for collection in db.list_collection_names():
    stats = db.command("collstats", str(collection))
    total_index = total_index + stats['totalIndexSize']
    print(collection + " size: " + common.sizeof_fmt(stats['totalIndexSize']))

print("--------------------")
print("Total Index Size: " + common.sizeof_fmt(total_index))
# Out:
# apps size: 28.0 MiB
# twitchhistorical size: 835.1 MiB
# pricehistory size: 2.3 GiB
# topgames size: 297.2 MiB
# isthereanydealhistory size: 5.3 MiB
# opencritic size: 680.0 KiB
# bandwidth size: 12.2 MiB
# isthereanydeal size: 2.6 MiB
# steamusers size: 60.4 MiB
# --------------------
# Total Index Size: 3.5 GiB
