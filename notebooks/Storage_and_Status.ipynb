# %%
import sys, os
from pymongo import MongoClient

from plotly.offline import init_notebook_mode, iplot
from plotly.graph_objs import *

# https://stackoverflow.com/questions/41323423/plotly-inside-jupyter-notebook-python
init_notebook_mode(connected=True) # initiate notebook for offline plot

import pandas as pd
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
sys.path.append("..")
import config # ../config.py
import common # ../common.py

# run on Antec
config.mongodb_ip = "192.168.1.140"

client = MongoClient(host=config.mongodb_ip, port=config.mongodb_port)
db = client['steam']

# %% [markdown]
# ## Failed appids excluded from future attempts or analysis

# %%
failed_appids_df = pd.DataFrame(list(db['apps'].find({"failureCount": {"$gte":3}}, {"appid":1,"name":1,"_id":False})))
failed_appids_df
# Out:
#          appid                                               name
# 0         3402                           Hammer Heads Deluxe Demo
# 1         3442                           Rocket Mania Deluxe Demo
# 2         5803                                      Darwinia_ESRB
# 3        12630                                Legend: Hand of God
# 4        15310                    The Settlers: Heritage of Kings
# 5        19930     The Settlers: Rise of an Empire Gold Edition
# 6        23330                              The Last Remnant Demo
# 7        33220             Tom Clancy's Splinter Cell: Conviction
# 8        33910                                             Arma 2
# 9        34000                              Football Manager 2010
# 10       41010               Serious Sam HD: The Second Encounter
# 11       47900                            Dragon Age II (Retired)
# 12       50146               Mafia II - The Betrayal of Jimmy DLC
# 13       50147                    Mafia II - Joe's Adventures DLC
# 14       55010                                      Flotilla Demo
# 15       55030                                    Air Forte Demo
# 16       55050                           Atom Zombie Smasher Demo
# 17       63010                                       HOARD - Demo
# 18       63600                                           realMyst
# 19       71270                              Football Manager 2012
# 20       81674                          Ticket to Ride Trailer EN
# 21       81675                          Ticket to Ride Trailer DE
# 22       81676                          Ticket to Ride Trailer FR
# 23       92230                      Gundemonium Recollection Demo
# 24       92240                                Hitogata Happa Demo
# 25       92250                                  GundeadliGne Demo
# 26      205120               Choplifter HD - Zombie Zombie Zombie
# 27      205140                  Choplifter HD - Albatross Chopper
# 28      207890                              Football Manager 2013
# 29      210897              Crusader Kings II: African Portraits
# ...        ...                                                ...
# 14129  1368680                                      SAWMOUTh Demo
# 14130  1373050                                   I am Savage 她不香吗
# 14131  1374510                                       Odore Kanojo
# 14132  1374530                            Guild of Ascension Demo
# 14133  1371140                                    SORRY FOR WHAT?
# 14134  1294330                   Syystem - The Phantom Train Demo
# 14135  1264960                                           SAWMOUTh
# 14136  1376400                                  XMOD MODDING TOOL
# 14137  1361250    Necronator: Dead Wrong - Special Commander Skin
# 14138  1370310                                      Jewel of Kuru
# 14139  1142400                                     New Zealand VR
# 14140  1364440     System Shock: Enhanced Edition - Bonus Content
# 14141  1333174  FAIRY TAIL: DDX Only Lucy's Costume Gust Colla...
# 14142  1333179    FAIRY TAIL: Wendy's Costume "Fairy Tail Team A"
# 14143  1333175    FAIRY TAIL: Natsu's Costume "Fairy Tail Team A"
# 14144  1333176     FAIRY TAIL: Lucy's Costume "Fairy Tail Team A"
# 14145  1333178     FAIRY TAIL: Erza's Costume "Fairy Tail Team A"
# 14146  1380950                   Fadeout Dedicated Server (alpha)
# 14147  1333177     FAIRY TAIL: Gray's Costume "Fairy Tail Team A"
# 14148  1361740           Die drei ??? - Fluch des Flaschenteufels
# 14149  1316470                 Warfare 1944 Beta Dedicated Server
# 14150  1382420                                Tomatenquark Server
# 14151  1090160              NTBSS: Lobby Action - Lightning Blade
# 14152  1307430                         Naval Action - Trincomalee
# 14153  1385360                                  Crimson Core Demo
# 14154  1362180                 FAIRY TAIL: FAIRY TAIL Season Pass
# 14155  1385000  Tree of Savior Japan - Splash August 2020 OST ...
# 14156  1348150  BIOHAZARD RE:3 Z Version - All In-game Rewards...
# 14157  1366910      For Honor - Warmonger Hero - Uplay Activation
# 14158  1387540  Assetto Corsa - Ferrari Hublot Esports Series ...
#
# [14159 rows x 2 columns]

# %%
grouped_df = db['apps'].aggregate([
{"$match":
    {"$or": [{"failureCount": {"$lt": 3}}, {"failureCount": {"$exists": False}}]}
},
{"$group":  {"_id": {"$dateToString": {"format": "%Y-%m-%d", "date": "$updated_date"}},
             "count" : { "$sum" : 1} } },
{"$sort": {"_id": 1}}
])

grouped_df = pd.DataFrame(list(grouped_df))
grouped_df.rename(columns={grouped_df.columns[0] : 'updated_date'}, inplace=True)
grouped_df
# Out:
#    updated_date  count
# 0    2020-07-21   1915
# 1    2020-07-22   3661
# 2    2020-07-23   3480
# 3    2020-07-24   3347
# 4    2020-07-25   3946
# 5    2020-07-26   3481
# 6    2020-07-27   3489
# 7    2020-07-28   3408
# 8    2020-07-29   3730
# 9    2020-07-30   3513
# 10   2020-07-31   3443
# 11   2020-08-01   3987
# 12   2020-08-02   3511
# 13   2020-08-03   2987
# 14   2020-08-04   3549
# 15   2020-08-05   3477
# 16   2020-08-06   3617
# 17   2020-08-07   3563
# 18   2020-08-08   3554
# 19   2020-08-09   3745
# 20   2020-08-10   3573
# 21   2020-08-11   3479
# 22   2020-08-12   4032
# 23   2020-08-13   3478
# 24   2020-08-14   3479
# 25   2020-08-15   2490

# %% [markdown]
# ## Large numbers of old AppID entries means `refreshsteam.py` needs to be run.  This excludes consistently failed appids.

# %%
# https://plot.ly/python/bar-charts/

data = [Bar(
        x=grouped_df['updated_date'],
        y=grouped_df['count']
    )]

layout = Layout(
        title='AppIDs By Last Updated Date',
        xaxis=dict(
            title='Date'
        ),
        yaxis=dict(
            title='Count'
        )
    )

fig = Figure(data=data, layout=layout)

iplot(fig)
# Out:
# <div id="ad72cbd0-3d92-4185-aded-6374948b68c3" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("ad72cbd0-3d92-4185-aded-6374948b68c3", [{"y": [1915, 3661, 3480, 3347, 3946, 3481, 3489, 3408, 3730, 3513, 3443, 3987, 3511, 2987, 3549, 3477, 3617, 3563, 3554, 3745, 3573, 3479, 4032, 3478, 3479, 2490], "type": "bar", "x": ["2020-07-21", "2020-07-22", "2020-07-23", "2020-07-24", "2020-07-25", "2020-07-26", "2020-07-27", "2020-07-28", "2020-07-29", "2020-07-30", "2020-07-31", "2020-08-01", "2020-08-02", "2020-08-03", "2020-08-04", "2020-08-05", "2020-08-06", "2020-08-07", "2020-08-08", "2020-08-09", "2020-08-10", "2020-08-11", "2020-08-12", "2020-08-13", "2020-08-14", "2020-08-15"], "uid": "17c3e695-f690-4a8c-bce3-f1fdaaeb7674"}], {"yaxis": {"title": {"text": "Count"}}, "xaxis": {"title": {"text": "Date"}}, "title": {"text": "AppIDs By Last Updated Date"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("ad72cbd0-3d92-4185-aded-6374948b68c3"));});</script>

# %%
grouped_df = db['pricehistory'].aggregate([
{"$match": {}},
{"$group":  {"_id": {"$dateToString": {"format": "%Y-%m-%d", "date": "$date"}},
             "count" : { "$sum" : 1} } },
{"$sort": {"_id": 1}}
])
},
{"$group":  {"_id": {"$dateToString": {"format": "%Y-%m-%d", "date": "$date"}},
             "count" : { "$sum" : 1} } },
{"$sort": {"_id": 1}}
])

grouped_df = pd.DataFrame(list(grouped_df))
grouped_df.rename(columns={grouped_df.columns[0] : 'date'}, inplace=True)
grouped_df
# Out:
#            date  count
# 0    2018-12-19    119
# 1    2018-12-20    340
# 2    2018-12-21    751
# 3    2018-12-22   1021
# 4    2018-12-23    932
# 5    2018-12-24    980
# 6    2018-12-25    938
# 7    2018-12-26    924
# 8    2018-12-27   1106
# 9    2018-12-28   1287
# 10   2018-12-29   1219
# 11   2018-12-30   1176
# 12   2018-12-31   1214
# 13   2019-01-01    943
# 14   2019-01-03    346
# 15   2019-01-05    617
# 16   2019-01-06    717
# 17   2019-01-07    134
# 18   2019-01-08    170
# 19   2019-01-09    351
# 20   2019-01-10     62
# 21   2019-01-11    267
# 22   2019-01-12    363
# 23   2019-01-13    409
# 24   2019-01-14    631
# 25   2019-01-15    626
# 26   2019-01-16    628
# 27   2019-01-17    597
# 28   2019-01-18    600
# 29   2019-01-19    627
# ..          ...    ...
# 553  2020-07-20    622
# 554  2020-07-21    629
# 555  2020-07-22    628
# 556  2020-07-23    627
# 557  2020-07-24    797
# 558  2020-07-25    804
# 559  2020-07-26    642
# 560  2020-07-27    626
# 561  2020-07-28    631
# 562  2020-07-29    631
# 563  2020-07-30    627
# 564  2020-07-31    630
# 565  2020-08-01    630
# 566  2020-08-02    834
# 567  2020-08-03    883
# 568  2020-08-04    674
# 569  2020-08-05    624
# 570  2020-08-06    627
# 571  2020-08-07    627
# 572  2020-08-08    632
# 573  2020-08-09    628
# 574  2020-08-10    631
# 575  2020-08-11    625
# 576  2020-08-12    627
# 577  2020-08-13    624
# 578  2020-08-14    423
# 579  2020-08-15    105
# 580  2020-08-22    234
# 581  2020-08-23    303
# 582  2020-08-24     68
#
# [583 rows x 2 columns]

# %% [markdown]
# ## These are the number of records we have per day for the `steamusers` Mongo collection.  This is created using the `steamusers.py` script.

# %%
# https://plot.ly/python/bar-charts/

data = [Bar(
        x=grouped_df['date'],
        y=grouped_df['count']
    )]

layout = Layout(
        title='Distribution of Records Per Day for steamusers',
        xaxis=dict(
            title='Date'
        ),
        yaxis=dict(
            title='Records Count'
        )
    )

fig = Figure(data=data, layout=layout)

iplot(fig)
# Out:
# <div id="3648ae4e-1ceb-4bbf-bcef-6cddd4f867b6" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("3648ae4e-1ceb-4bbf-bcef-6cddd4f867b6", [{"y": [119, 340, 751, 1021, 932, 980, 938, 924, 1106, 1287, 1219, 1176, 1214, 943, 346, 617, 717, 134, 170, 351, 62, 267, 363, 409, 631, 626, 628, 597, 600, 627, 629, 630, 628, 629, 754, 755, 622, 623, 621, 621, 626, 629, 628, 520, 348, 452, 625, 620, 622, 622, 625, 629, 624, 631, 627, 626, 624, 600, 607, 630, 633, 642, 635, 628, 626, 563, 506, 563, 622, 604, 640, 643, 630, 628, 631, 629, 630, 641, 642, 701, 728, 620, 622, 625, 627, 338, 297, 586, 625, 567, 565, 625, 628, 627, 470, 467
019-01-05", "2019-01-06", "2019-01-07", "2019-01-08", "2019-01-09", "2019-01-10", "2019-01-11", "2019-01-12", "2019-01-13", "2019-01-14", "2019-01-15", "2019-01-16", "2019-01-17", "2019-01-18", "2019-01-19", "2019-01-20", "2019-01-21", "2019-01-22", "2019-01-23", "2019-01-24", "2019-01-25", "2019-01-26", "2019-01-27", "2019-01-28", "2019-01-29", "2019-01-30", "2019-01-31", "2019-02-01", "2019-02-02", "2019-02-03", "2019-02-04", "2019-02-05", "2019-02-06", "2019-02-07", "2019-02-08", "2019-02-09", "2019-02-1 ...

# %%
grouped_df = db['topgames'].aggregate([
{"$match": {}},
{"$group":  {"_id": {"$dateToString": {"format": "%Y-%m-%d", "date": "$date"}},
             "count" : { "$sum" : 1} } },
{"$sort": {"_id": 1}}
])

grouped_df = pd.DataFrame(list(grouped_df))
grouped_df.rename(columns={grouped_df.columns[0] : 'date'}, inplace=True)
grouped_df
# Out:
#            date  count
# 0    2019-01-08    300
# 1    2019-01-09   2300
# 2    2019-01-10    100
# 3    2019-01-13   4000
# 4    2019-01-14   9000
# 5    2019-01-15   8400
# 6    2019-01-16   9200
# 7    2019-01-17   8500
# 8    2019-01-18   9100
# 9    2019-01-19   5200
# 10   2019-01-20   9200
# 11   2019-01-21   8500
# 12   2019-01-22   9000
# 13   2019-01-23   8400
# 14   2019-01-24   9100
# 15   2019-01-25   8600
# 16   2019-01-26   8700
# 17   2019-01-27   8600
# 18   2019-01-28   8200
# 19   2019-01-29   8700
# 20   2019-01-30   8100
# 21   2019-01-31   8600
# 22   2019-02-01   8200
# 23   2019-02-02   8600
# 24   2019-02-03   7000
# 25   2019-02-05   4100
# 26   2019-02-06   8700
# 27   2019-02-07   8200
# 28   2019-02-08   8500
# 29   2019-02-09   8200
# ..          ...    ...
# 518  2020-07-17   7800
# 519  2020-07-18    900
# 520  2020-07-19   8000
# 521  2020-07-20   7500
# 522  2020-07-21   8100
# 523  2020-07-22   8500
# 524  2020-07-23   8200
# 525  2020-07-24   8700
# 526  2020-07-25   8700
# 527  2020-07-26   8600
# 528  2020-07-27   8300
# 529  2020-07-28   8700
# 530  2020-07-29   8400
# 531  2020-07-30   8800
# 532  2020-07-31   8700
# 533  2020-08-01   8700
# 534  2020-08-02   8800
# 535  2020-08-03   7800
# 536  2020-08-04   8500
# 537  2020-08-05   8500
# 538  2020-08-06   8600
# 539  2020-08-07   8800
# 540  2020-08-08   8800
# 541  2020-08-09   8700
# 542  2020-08-10   8700
# 543  2020-08-11   8700
# 544  2020-08-12   8700
# 545  2020-08-13   8700
# 546  2020-08-14   8600
# 547  2020-08-15   5500
#
# [548 rows x 2 columns]

# %% [markdown]
# ## These are the number of entries we have per day for the `topgames` Mongo collection.  Each query returns the current top 100 games being played.  This is run every 15 minutes.

# %%
# https://plot.ly/python/bar-charts/

data = [Bar(
        x=grouped_df['date'],
        y=grouped_df['count']
    )]

layout = Layout(
        title='Distribution of Records Per Day for topgames',
        xaxis=dict(
            title='Date'
        ),
        yaxis=dict(
            title='Records Count'
        )
    )

fig = Figure(data=data, layout=layout)

iplot(fig)
# Out:
# <div id="68a83dc6-0993-4542-aaff-26c34ce4637c" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("68a83dc6-0993-4542-aaff-26c34ce4637c", [{"y": [300, 2300, 100, 4000, 9000, 8400, 9200, 8500, 9100, 5200, 9200, 8500, 9000, 8400, 9100, 8600, 8700, 8600, 8200, 8700, 8100, 8600, 8200, 8600, 7000, 4100, 8700, 8200, 8500, 8200, 8600, 8300, 8600, 8100, 8700, 8100, 8700, 7600, 7400, 8700, 8100, 8700, 8100, 8500, 8200, 8600, 8600, 8600, 8200, 8700, 8100, 8600, 8100, 8700, 8200, 8600, 8100, 8600, 8100, 8700, 8600, 8600, 8000, 8600, 8000, 600, 7200, 8700, 8100, 6400, 7100, 8300, 8200, 7900, 1800, 4600, 8700, 700
, 8600, 8700, 8100, 8700, 8700, 8700, 8700, 8700, 8600, 8800, 8700, 8700, 8800, 8500, 8700, 8800, 8600, 8800, 8700, 8800, 8500, 8500, 8000, 6200, 6600, 8700, 7700, 700, 3900, 8700, 8500, 8600, 8800, 8800, 8300, 8500, 8200, 8200, 8600, 8700, 8800, 8800, 8100, 8400, 8700, 8700, 8700, 8600, 8600, 8200, 8500, 8300, 8700, 8500, 8600, 2400, 5800, 8500, 8500, 8600, 8700, 8700, 8800, 8600, 8800, 8700, 8700, 8600, 7800, 900, 8000, 7500, 8100, 8500, 8200, 8700, 8700, 8600, 8300, 8700, 8400, 8800, 8700, 8700, 8800, 7800, 8500, 8500, 8600, 8800, 8800, 8700, 8700, 8700, 8700, 8700, 8600, 5500], "type": "bar", "x": ["2019-01-08", "2019-01-09", "2019-01-10", "2019-01-13", "2019-01-14", "2019-01-15", "2019-01-16", "2019-01-17", "2019-01-18", "2019-01-19", "2019-01-20", "2019-01-21", "2019-01-22", "2019-01-23", "2019-01-24", "2019-01-25", "2019-01-26", "2019-01-27", "2019-01-28", "2019-01-29", "2019-01-30", "2019-01-31", "2019-02-01", "2019-02-02", "2019-02-03", "2019-02-05", " ...

# %%
grouped_df = db['apps'].aggregate([
{"$match": {"type": {"$in": ["game", "dlc"]}}},
{"$group":  {"_id": {"$dateToString": {"format": "%Y-%m-%d", "date": "$reviews.last_updated"}},
             "count" : { "$sum" : 1} } },
{"$sort": {"_id": 1}}
])

grouped_df = pd.DataFrame(list(grouped_df))
grouped_df.rename(columns={grouped_df.columns[0] : 'date'}, inplace=True)
grouped_df
# Out:
#           date  count
# 0         None  70600
# 1   2020-07-26      5
# 2   2020-07-27      3
# 3   2020-07-28      2
# 4   2020-08-01     50
# 5   2020-08-02      2
# 6   2020-08-03      5
# 7   2020-08-04    719
# 8   2020-08-05   1246
# 9   2020-08-06   1409
# 10  2020-08-07    740
# 11  2020-08-08    121
# 12  2020-08-09     67
# 13  2020-08-10      4
# 14  2020-08-11     32
# 15  2020-08-12     29
# 16  2020-08-13     20
# 17  2020-08-14     27
# 18  2020-08-15      9
# 19  2020-08-18      3
# 20  2020-08-24     50

# %% [markdown]
# ## These are the number of Steam games where we have review information from Steam and when they were last updated

# %%
# https://plot.ly/python/bar-charts/

data = [Bar(
        x=grouped_df['date'],
        y=grouped_df['count']
    )]

layout = Layout(
        title='Distribution of Steam game reviews per day',
        xaxis=dict(
            title='Date'
        ),
        yaxis=dict(
            title='Records Count'
        )
    )

fig = Figure(data=data, layout=layout)

iplot(fig)
# Out:
# <div id="01737e98-2d98-46fc-b2e5-ea45f1410fc2" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("01737e98-2d98-46fc-b2e5-ea45f1410fc2", [{"y": [70600, 5, 3, 2, 50, 2, 5, 719, 1246, 1409, 740, 121, 67, 4, 32, 29, 20, 27, 9, 3, 50], "type": "bar", "x": [null, "2020-07-26", "2020-07-27", "2020-07-28", "2020-08-01", "2020-08-02", "2020-08-03", "2020-08-04", "2020-08-05", "2020-08-06", "2020-08-07", "2020-08-08", "2020-08-09", "2020-08-10", "2020-08-11", "2020-08-12", "2020-08-13", "2020-08-14", "2020-08-15", "2020-08-18", "2020-08-24"], "uid": "ce811beb-2d1f-49ba-8857-9b85e46f2e68"}], {"yaxis": {"title": {"text": "Records Count"}}, "xaxis": {"title": {"text": "Date"}}, "title": {"text": "Distribution of Steam game reviews per day"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("01737e98-2d98-46fc-b2e5-ea45f1410fc2"));});</script>

# %%
steam_grouped_df = db['opencritic'].aggregate([
{"$match": {"steamId": {"$exists": True, "$ne": None}}},
{"$group":  {"_id": {"$dateToString": {"format": "%Y-%m-%d", "date": "$date"}},
             "count" : { "$sum" : 1} } },
{"$sort": {"_id": 1}}
])

steam_grouped_df = pd.DataFrame(list(steam_grouped_df))
steam_grouped_df.rename(columns={steam_grouped_df.columns[0] : 'date'}, inplace=True)

nonsteam_grouped_df = db['opencritic'].aggregate([
{"$match": {"$or": [{"steamId": {"$exists": False}}, {"steamId": None}]}},
{"$group":  {"_id": {"$dateToString": {"format": "%Y-%m-%d", "date": "$date"}},
             "count" : { "$sum" : 1} } },
{"$sort": {"_id": 1}}
])

nonsteam_grouped_df = pd.DataFrame(list(nonsteam_grouped_df))
nonsteam_grouped_df.rename(columns={nonsteam_grouped_df.columns[0] : 'date'}, inplace=True)

print(steam_grouped_df)
print(nonsteam_grouped_df)
# Out:
#           date  count
# 0   2020-07-30    175
# 1   2020-07-31    304
# 2   2020-08-01    285
# 3   2020-08-02    294
# 4   2020-08-03    275
# 5   2020-08-04    303
# 6   2020-08-05    310
# 7   2020-08-06    292
# 8   2020-08-07    281
# 9   2020-08-08    256
# 10  2020-08-09    317
# 11  2020-08-10    322
# 12  2020-08-11    326
# 13  2020-08-12    284
# 14  2020-08-13    296
# 15  2020-08-14    327
# 16  2020-08-15    164
#           date  count
# 0   2020-07-29      1
# 1   2020-07-30    159
# 2   2020-07-31    256
# 3   2020-08-01    272
# 4   2020-08-02    267
# 5   2020-08-03    202
# 6   2020-08-04    253
# 7   2020-08-05    220
# 8   2020-08-06    259
# 9   2020-08-07    274
# 10  2020-08-08    303
# 11  2020-08-09    237
# 12  2020-08-10    231
# 13  2020-08-11    228
# 14  2020-08-12    280
# 15  2020-08-13    271
# 16  2020-08-14    237
# 17  2020-08-15    155

# %% [markdown]
# ## This is the breakdown of OpenCritic data we have by last accessed/updated date.

# %%
# https://plot.ly/python/bar-charts/#stacked-bar-chart

steamTrace = Bar(
    x=steam_grouped_df['date'],
    y=steam_grouped_df['count'],
    name='Games w/steamId'
)
nonSteamTrace = Bar(
    x=nonsteam_grouped_df['date'],
    y=nonsteam_grouped_df['count'],
    name='Games without steamId'
)

data = [steamTrace, nonSteamTrace]

layout = Layout(
        title='Distribution of OpenCritic Records Per Day Grouped By steamId',
        xaxis=dict(
            title='Date'
        ),
        yaxis=dict(
            title='Records Count'
        ),
        barmode='stack'
    )

fig = Figure(data=data, layout=layout)

iplot(fig)
# Out:
# <div id="1485064e-54a2-45f1-b3a4-e3160b97d451" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("1485064e-54a2-45f1-b3a4-e3160b97d451", [{"y": [175, 304, 285, 294, 275, 303, 310, 292, 281, 256, 317, 322, 326, 284, 296, 327, 164], "name": "Games w/steamId", "type": "bar", "x": ["2020-07-30", "2020-07-31", "2020-08-01", "2020-08-02", "2020-08-03", "2020-08-04", "2020-08-05", "2020-08-06", "2020-08-07", "2020-08-08", "2020-08-09", "2020-08-10", "2020-08-11", "2020-08-12", "2020-08-13", "2020-08-14", "2020-08-15"], "uid": "c8749b5a-3b04-4bc5-b011-c4d870f66d50"}, {"y": [1, 159, 256, 272, 267, 202, 253, 220, 259, 274, 303, 237, 231, 228, 280, 271, 237, 155], "name": "Games without steamId", "type": "bar", "x": ["2020-07-29", "2020-07-30", "2020-07-31", "2020-08-01", "2020-08-02", "2020-08-03", "2020-08-04", "2020-08-05", "2020-08-06", "2020-08-07", "2020-08-08", "2020-08-09", "2020-08-10", "2020-08-11", "2020-08-12", "2020-08-13", "2020-08-14", "2020-08-15"], "uid": "fd8ec84b-d199-46c8-a8cb-6fde7f61e25b"}], {"yaxis": {"title": {"text": "Records Count"}}, "barmode": "stack", "xaxis": {"title": {"text": "Date"}}, "title": {"text": "Distribution of OpenCritic Records Per Day Grouped By steamId"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("1485064e-54a2-45f1-b3a4-e3160b97d451"));});</script>

# %% [markdown]
# ## This is counts of Twitch records by day grouped by a tie to Steam

# %%
steam_grouped_df = db['twitchhistorical'].aggregate([
{"$match": {"steamId": {"$exists": True}}},
{"$group":  {"_id": {"$dateToString": {"format": "%Y-%m-%d", "date": "$date"}},
             "count" : { "$sum" : 1} } },
{"$sort": {"_id": 1}}
])

steam_grouped_df = pd.DataFrame(list(steam_grouped_df))
steam_grouped_df.rename(columns={steam_grouped_df.columns[0] : 'date'}, inplace=True)

nonsteam_grouped_df = db['twitchhistorical'].aggregate([
{"$match": {"steamId": {"$exists": False}}},
{"$group":  {"_id": {"$dateToString": {"format": "%Y-%m-%d", "date": "$date"}},
             "count" : { "$sum" : 1} } },
{"$sort": {"_id": 1}}
])

nonsteam_grouped_df = pd.DataFrame(list(nonsteam_grouped_df))
nonsteam_grouped_df.rename(columns={nonsteam_grouped_df.columns[0] : 'date'}, inplace=True)

# https://plot.ly/python/bar-charts/#stacked-bar-chart

steamTrace = Bar(
    x=steam_grouped_df['date'],
    y=steam_grouped_df['count'],
    name='Games w/steamId'
)
nonSteamTrace = Bar(
    x=nonsteam_grouped_df['date'],
    y=nonsteam_grouped_df['count'],
    name='Games without steamId'
)

data = [steamTrace, nonSteamTrace]

layout = Layout(
        title='Distribution of Twitch Records Per Day Grouped By steamId',
        xaxis=dict(
            title='Date'
        ),
        yaxis=dict(
            title='Records Count'
        ),
        barmode='stack'
    )

fig = Figure(data=data, layout=layout)

iplot(fig)
# Out:
# <div id="78f61b5c-d954-43c5-b260-a86c023daa45" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("78f61b5c-d954-43c5-b260-a86c023daa45", [{"y": [24004, 16988, 18423, 18033, 19570, 17635, 17365, 14602, 17003, 16842, 4636, 7878, 7679, 5402, 7767, 5038, 8103, 7446, 4973, 7904, 8347, 5043, 7491, 8098, 4942, 7569, 7905, 4677, 7870, 7759, 5253, 8086, 5012, 7276, 8014, 4765, 7461, 7416, 4703, 7671, 5081, 7926, 5081, 7711, 7659, 4917, 7515, 7925, 5854, 8591, 5299, 7855, 7892, 5121, 7951, 8501, 5322, 8582, 8629, 5326, 8840, 5040, 8060, 7973, 4458, 7984, 7195, 4812, 7097, 7254, 4847, 7107, 4645, 8111, 7715, 4937, 7689, 7598, 4518, 7287, 6589, 4291, 7376, 4717, 7220, 6806, 4576, 7506, 7084, 4562, 7351, 7130, 4358, 7045, 4421, 6881, 4446, 4803, 6920, 4450, 7379, 7371, 4366, 7605, 7585, 4920, 7708, 7728, 4327, 7670, 5129, 7145, 7838, 4291, 7129, 6957, 4814, 7580, 5076, 6980, 7024, 4292, 7004, 4322, 5104, 4382, 7378, 6780, 4585, 7332, 4403, 6626, 7503, 4558, 6845, 7688, 4521, 7427, 7380, 5066, 7505, 7004, 4923, 7567, 4848, 7605, 7861, 4983, 7195, 7430, 4581, 7415, 8074, 4834, 8430, 8242, 5481, 8384, 5289, 7802, 8323, 5447, 7844, 7844, 5023, 8172, 8232, 5057, 8386, 5286, 8001, 7818, 5206, 8127, 8809, 5485, 8439, 8285, 5561, 9022, 6023, 8640, 9124, 5619, 8416, 8723, 5468, 8687, 8805, 6098, 8855, 9146, 5680, 8938, 5702, 8383, 8458, 5506, 5520, 8569, 5451, 8810, 5882, 8732, 5714, 8660, 8499, 5349, 8702, 6165, 9069, 8503, 2623, 8487, 5671, 9008, 9093, 6049, 8639, 8606, 5318, 9172, 5745, 8576, 9280, 5474, 8977, 7667, 5235, 8493, 8190, 5744, 8153, 5485, 7748, 7880, 5238, 8651, 8056, 4985, 7881, 7125, 4709, 8625, 8738, 5638, 8785, 8586, 5542, 8537, 5584, 8436, 9013, 5317, 8501, 8715, 5732, 8964, 9125, 6347, 7796, 5629, 9105, 8551, 5922, 8833, 6059, 8947, 8679, 5548, 8531, 8931, 5742, 8929, 9339, 6234, 8918, 9267, 6069, 9330, 6489, 9314, 9355, 6025, 8683, 9526, 6703, 9497, 9472, 6386, 9445, 8883, 6026, 9031, 6610, 5619, 6441, 5958, 5836, 2868, 8108, 5336, 8966, 8289, 6063, 9554, 6189, 9547, 9057, 5739, 8777, 8494, 5234, 8728, 8640, 5872, 8454, 5610, 8499, 9101, 6268, 8667, 8439, 5883, 8446, 6163, 3280, 2873, 9251, 8756, 5816, 9638, 8876, 6123, 9270, 7541, 8009, 9899, 6423, 8995, 6053, 6117, 9799, 6165, 9170, 9334, 5687, 5922, 9448, 6310, 9402, 9550, 6111, 9861, 10008, 6088, 6375, 6236, 10150, 9692, 6463, 9636, 6132, 10132, 10050, 6519, 9853, 6466], "name": "Games w/steamId", "type": "bar", "x": ["2019-07-14", "2019-07-15", "2019-07-16", "2019-07-17", "2019-07-18", "2019-07-19", "2019-07-20", "2019-07-21", "2019-07-22", "2019-07-23", "2019-07-24", "2019-07-25", "2019-07-26", "2019-07-27", "2019-07-28", "2019-07-29", "2019-07-30", "2019-07-31", "2019-08-01", "2019-08-02", "2019-08-03", "2019-08-04", "2019-08-05", "2019-08-06", "2019-08-07", "2019-08-08", "2019-08-09", "2019-08-10", "2019-08-11", "2019-08-12", "2019-08-13", "2019-08-14", "2019-08-15", "2019-08-16", "2019-08-17", "2019-08-18", "2019-08-19", "2019-08-20", "2019-08-21", "2019-08-22", "2019-08-23", "2019-08-24", "2019-08-25", "2019-08-26", "2019-08-27", "2019-08-28", "2019-08-29", "2019-08-30", "2019-08-31", "2019-09-01", "2019-09-02", "2019-09-03", "2019-09-04", "2019-09-05", "2019-09-06", "2019-09-07", "2019-09-08", "2019-09-09", "2019-09-10", "2019-09-11", "2019-09-12", "2019-09-13", "2019-09-14", "2019-09-15", "2019-09-16", "2019-09-17", "2019-09-18", "2019-09-19", "2019-09-20", "2019-09-21", "2019-09-22", "2019-09-23", "2019-09-24", "2019-09-25", "2019-09-26", "2019-09-27", "2019-09-28", "2019-09-29", "2019-09-30", "2019-10-01", "2019-10-02", "2019-10-03", "2019-10-04", "2019-10-05", "2019-10-06", "2019-10-07", "2019-10-08", "2019-10-09", "2019-10-10", "2019-10-11", "2019-10-12", "2019-10-13", "2019-10-14", "2019-10-15", "2019-10-16", "2019-10-17", "2019-10-18", "2019-10-19", "2019-10-20", "2019-10-21" ...

# %%
grouped_df = db['bandwidth'].aggregate([
{"$match": {}},
{"$group":  {"_id": {"$dateToString": {"format": "%Y-%m-%d", "date": "$date"}},
             "bytes" : { "$sum" : "$bytes"} } },
{"$sort": {"_id": 1}}
])

grouped_df = pd.DataFrame(list(grouped_df))
grouped_df.rename(columns={grouped_df.columns[0] : 'date'}, inplace=True)
grouped_df
# Out:
#          date   bytes
# 0  2020-08-24  162778

# %% [markdown]
# ## Bandwidth used

# %%
# https://plot.ly/python/bar-charts/

data = [Bar(
        x=grouped_df['date'],
        y=grouped_df['bytes']
    )]

layout = Layout(
        title='Data downloaded per day',
        xaxis=dict(
            title='Date'
        ),
        yaxis=dict(
            title='Bytes'
        )
    )

fig = Figure(data=data, layout=layout)

iplot(fig)
# Out:
# <div id="58eca0b4-8a2f-4383-bc9f-8a35d64e0851" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("58eca0b4-8a2f-4383-bc9f-8a35d64e0851", [{"y": [162778], "type": "bar", "x": ["2020-08-24"], "uid": "92244e51-0d4f-4846-8dde-10cb8836a0b9"}], {"yaxis": {"title": {"text": "Bytes"}}, "xaxis": {"title": {"text": "Date"}}, "title": {"text": "Data downloaded per day"}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("58eca0b4-8a2f-4383-bc9f-8a35d64e0851"));});</script>

# %% [markdown]
# ## Storage and disk usage information

# %%
for collection in db.list_collection_names():
    stats = db.command("collstats", str(collection))
    print(collection + " size: " + common.sizeof_fmt(stats['size']))

print("--------------------")
stats = db.command("dbstats")
print("Total Database Size: " + common.sizeof_fmt(stats['dataSize']))
# Out:
# opencritic size: 124.0 MiB
# apps size: 746.6 MiB
# bandwidth size: 94.0 B
# twitchhistorical size: 2.7 GiB
# pricehistory size: 1.3 GiB
# steamusers size: 26.6 MiB
# topgames size: 788.2 MiB
# --------------------
# Total Database Size: 5.7 GiB

# %% [markdown]
# ## Check index size across collections

# %%
total_index = 0
for collection in db.list_collection_names():
    stats = db.command("collstats", str(collection))
    total_index = total_index + stats['totalIndexSize']
    print(collection + " size: " + common.sizeof_fmt(stats['totalIndexSize']))

print("--------------------")
print("Total Index Size: " + common.sizeof_fmt(total_index))
# Out:
# opencritic size: 468.0 KiB
# apps size: 5.5 MiB
# bandwidth size: 72.0 KiB
# twitchhistorical size: 252.6 MiB
# pricehistory size: 410.8 MiB
# steamusers size: 11.5 MiB
# topgames size: 86.4 MiB
# --------------------
# Total Index Size: 767.3 MiB
