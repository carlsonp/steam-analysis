# %%
import sys, os
from pymongo import MongoClient

from plotly.offline import init_notebook_mode, iplot
from plotly.graph_objs import *

# https://stackoverflow.com/questions/41323423/plotly-inside-jupyter-notebook-python
init_notebook_mode(connected=True) # initiate notebook for offline plot

import pandas as pd
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
sys.path.append("..")
import config # ../config.py
import common # ../common.py

# run on Asus laptop Mongo database
#config.mongodb_ip = "192.168.1.124"
# run on Dell
config.mongodb_ip = "192.168.1.171"

client = MongoClient(host=config.mongodb_ip, port=config.mongodb_port)
db = client['steam']

# %% [markdown]
# ## Failed appids excluded from future attempts or analysis

# %%
failed_appids_df = pd.DataFrame(list(db['apps'].find({"failureCount": {"$gte":3}}, {"appid":1,"name":1,"_id":False})))
failed_appids_df
# Out:
#          appid                                               name
# 0        12630                                Legend: Hand of God
# 1        15310                    The Settlers: Heritage of Kings
# 2        19930     The Settlers: Rise of an Empire Gold Edition
# 3        23330                              The Last Remnant Demo
# 4        33220             Tom Clancy's Splinter Cell: Conviction
# 5        33910                                             Arma 2
# 6        34000                              Football Manager 2010
# 7        41010               Serious Sam HD: The Second Encounter
# 8        47900                                      Dragon Age II
# 9        55010                                      Flotilla Demo
# 10       55030                                    Air Forte Demo
# 11       55050                           Atom Zombie Smasher Demo
# 12       63010                                       HOARD - Demo
# 13       63600                                           realMyst
# 14       71270                              Football Manager 2012
# 15       81674                          Ticket to Ride Trailer EN
# 16       81675                          Ticket to Ride Trailer DE
# 17       81676                          Ticket to Ride Trailer FR
# 18       92230                      Gundemonium Recollection Demo
# 19       92240                                Hitogata Happa Demo
# 20       92250                                  GundeadliGne Demo
# 21      205120               Choplifter HD - Zombie Zombie Zombie
# 22      205140                  Choplifter HD - Albatross Chopper
# 23      207890                              Football Manager 2013
# 24      210897              Crusader Kings II: African Portraits
# 25      218510                               Planets Under Attack
# 26      227240                                   Construct 2 Free
# 27      231670                              Football Manager 2014
# 28      233250                             Planetary Annihilation
# 29      239570             Mark of the Ninja: Special Edition DLC
# ...        ...                                                ...
# 12711  1197190                                   Magical Princess
# 12712  1199590                     Cyber Pussy 2020 - Soundtracks
# 12713  1163030  SOULCALIBUR VI Season Pass 2 Bonus: SCIV and S...
# 12714  1191870                                       Goblin Times
# 12715  1170785  SD GUNDAM G GENERATION CROSS RAYS - DLC7 - Add...
# 12716  1170787  SD GUNDAM G GENERATION CROSS RAYS - DLC6 - Add...
# 12717  1170786  SD GUNDAM G GENERATION CROSS RAYS - DLC9 -Modi...
# 12718  1116270   SD GUNDAM G GENERATION CROSS RAYS - DLC5 - Ad...
# 12719  1170784  SD GUNDAM G GENERATION CROSS RAYS - DLC5 -Modi...
# 12720  1170789  SD GUNDAM G GENERATION CROSS RAYS - DLC5 -Char...
# 12721  1202290      SD GUNDAM G GENERATION CROSS RAYS - DLC5 Pack
# 12722  1177480                                              月牙楼风云
# 12723  1196141                           CODE VEIN - Venous Claws
# 12724  1195301                 Ironsight - Steam Freemium Package
# 12725  1185850      Two Point Hospital: Jingle Jam Jingle Jimjams
# 12726  1195290                                            Moncage
# 12727  1206620                                Soul Axiom Rebooted
# 12728  1199380                      Kingdoms and Castles Workshop
# 12729   928530                Prime & Load: 1776 Dedicated Server
# 12730  1210041          Anno 1800 – Holyday pack Uplay activation
# 12731   621240                 Galaxy in Turmoil Dedicated Server
# 12732  1204170                             Onset Dedicated Server
# 12733  1195300                       Ironsight - Holiday box 10+1
# 12734  1169370                           Necesse Dedicated Server
# 12735   341580                                       Figure World
# 12736   974724  JUMP FORCE Character Pack 8: Grimmjow Jaegerja...
# 12737   974725         JUMP FORCE Character Pack 9: Trafalgar Law
# 12738  1205670                                          吞食天地 2019
# 12739  1008080                                                ARK
# 12740  1180760                    Risk of Rain 2 Dedicated Server
#
# [12741 rows x 2 columns]

# %%
grouped_df = db['apps'].aggregate([
{"$match":
    {"$or": [{"failureCount": {"$lt": 3}}, {"failureCount": {"$exists": False}}]}
},
{"$group":  {"_id": {"$dateToString": {"format": "%Y-%m-%d", "date": "$updated_date"}},
             "count" : { "$sum" : 1} } },
{"$sort": {"_id": 1}}
])

grouped_df = pd.DataFrame(list(grouped_df))
grouped_df.rename(columns={grouped_df.columns[0] : 'updated_date'}, inplace=True)
grouped_df
# Out:
#    updated_date  count
# 0          None   1129
# 1    2019-11-26    907
# 2    2019-11-27   3309
# 3    2019-11-28   3873
# 4    2019-11-29   3333
# 5    2019-11-30   3350
# 6    2019-12-01   3349
# 7    2019-12-02   3846
# 8    2019-12-03   3354
# 9    2019-12-04   3436
# 10   2019-12-05   3599
# 11   2019-12-06   3126
# 12   2019-12-07   3427
# 13   2019-12-08   3420
# 14   2019-12-09   3954
# 15   2019-12-10   3397
# 16   2019-12-11   3340
# 17   2019-12-12   3834
# 18   2019-12-13   3385
# 19   2019-12-14   3370
# 20   2019-12-15   3383
# 21   2019-12-16   3770
# 22   2019-12-17   3338
# 23   2019-12-18   3452

# %% [markdown]
# ## Large numbers of old AppID entries means `refreshsteam.py` needs to be run.  This excludes consistently failed appids.

# %%
# https://plot.ly/python/bar-charts/

data = [Bar(
        x=grouped_df['updated_date'],
        y=grouped_df['count']
    )]

layout = Layout(
        title='AppIDs By Last Updated Date',
        xaxis=dict(
            title='Date'
        ),
        yaxis=dict(
            title='Count'
        )
    )

fig = Figure(data=data, layout=layout)

iplot(fig)
# Out:
# <div id="6e8755cd-cd99-4b39-ba9c-4ed19aeda9e5" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("6e8755cd-cd99-4b39-ba9c-4ed19aeda9e5", [{"uid": "ba0944e8-b243-4a94-9a1b-138edef72c7d", "y": [1129, 907, 3309, 3873, 3333, 3350, 3349, 3846, 3354, 3436, 3599, 3126, 3427, 3420, 3954, 3397, 3340, 3834, 3385, 3370, 3383, 3770, 3338, 3452], "x": [null, "2019-11-26", "2019-11-27", "2019-11-28", "2019-11-29", "2019-11-30", "2019-12-01", "2019-12-02", "2019-12-03", "2019-12-04", "2019-12-05", "2019-12-06", "2019-12-07", "2019-12-08", "2019-12-09", "2019-12-10", "2019-12-11", "2019-12-12", "2019-12-13", "2019-12-14", "2019-12-15", "2019-12-16", "2019-12-17", "2019-12-18"], "type": "bar"}], {"title": {"text": "AppIDs By Last Updated Date"}, "xaxis": {"title": {"text": "Date"}}, "yaxis": {"title": {"text": "Count"}}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("6e8755cd-cd99-4b39-ba9c-4ed19aeda9e5"));});</script>

# %%
grouped_df = db['pricehistory'].aggregate([
{"$match": {}},
{"$group":  {"_id": {"$dateToString": {"format": "%Y-%m-%d", "date": "$date"}},
             "count" : { "$sum" : 1} } },
{"$sort": {"_id": 1}}
])

grouped_df = pd.DataFrame(list(grouped_df))
grouped_df.rename(columns={grouped_df.columns[0] : 'date'}, inplace=True)
grouped_df
# Out:
#            date  count
# 0    2018-09-04   8215
# 1    2018-09-05  43441
# 2    2018-09-06  37421
# 3    2018-09-07  23655
# 4    2018-09-08  37188
# 5    2018-09-10   2963
# 6    2018-09-11  45999
# 7    2018-09-12  20210
# 8    2018-09-13    269
# 9    2018-09-14  37390
# 10   2018-09-15  37650
# 11   2018-09-17  13770
# 12   2018-09-18  23910
# 13   2018-09-20  45652
# 14   2018-09-22  36531
# 15   2018-09-24   6238
# 16   2018-09-25  34293
# 17   2018-09-27  36969
# 18   2018-09-28  36974
# 19   2018-09-30   9130
# 20   2018-10-01  27797
# 21   2018-10-03  36964
# 22   2018-10-05  37018
# 23   2018-10-06  23097
# 24   2018-10-07  13902
# 25   2018-10-09  37005
# 26   2018-10-12  37128
# 27   2018-10-14  37054
# 28   2018-10-17  37148
# 29   2018-10-20  37170
# ..          ...    ...
# 377  2019-11-19  27388
# 378  2019-11-20  28556
# 379  2019-11-21  28415
# 380  2019-11-22  28184
# 381  2019-11-23  28197
# 382  2019-11-24  27286
# 383  2019-11-25  28344
# 384  2019-11-26  23378
# 385  2019-11-27  17090
# 386  2019-11-28  13535
# 387  2019-11-29  12058
# 388  2019-11-30  13143
# 389  2019-12-01  13916
# 390  2019-12-02  15205
# 391  2019-12-03  15885
# 392  2019-12-04  16905
# 393  2019-12-05  17298
# 394  2019-12-06  18698
# 395  2019-12-07  19776
# 396  2019-12-08  20192
# 397  2019-12-09  20536
# 398  2019-12-10  21188
# 399  2019-12-11  21922
# 400  2019-12-12  23336
# 401  2019-12-13  22825
# 402  2019-12-14  24588
# 403  2019-12-15  25519
# 404  2019-12-16  27210
# 405  2019-12-17  27986
# 406  2019-12-18  28635
#
# [407 rows x 2 columns]

# %% [markdown]
# ## This is historical data from the `pricehistory` Mongo collection.  This is updated via the `updatepricehistory.py` script.

# %%
# https://plot.ly/python/bar-charts/

data = [Bar(
        x=grouped_df['date'],
        y=grouped_df['count']
    )]

layout = Layout(
        title='Distribution of Price History',
        xaxis=dict(
            title='Date'
        ),
        yaxis=dict(
            title='Records Count'
        )
    )

fig = Figure(data=data, layout=layout)

iplot(fig)
# Out:
# <div id="8b15afaf-f583-4bd1-a07e-b028e3ad4207" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("8b15afaf-f583-4bd1-a07e-b028e3ad4207", [{"uid": "a632f3de-a7e0-47e6-aba8-dc259f747da3", "y": [8215, 43441, 37421, 23655, 37188, 2963, 45999, 20210, 269, 37390, 37650, 13770, 23910, 45652, 36531, 6238, 34293, 36969, 36974, 9130, 27797, 36964, 37018, 23097, 13902, 37005, 37128, 37054, 37148, 37170, 37195, 22490, 14330, 37262, 3876, 33416, 37490, 37216, 36870, 19257, 18066, 37280, 37305, 37384, 37377, 37363, 37422, 27672, 9761, 37403, 37461, 37531, 37496, 37484, 37522, 24521, 13019, 37514, 36924, 37700, 37622, 26636, 37138, 37607, 37691, 37726, 37724, 37721, 37718, 52, 42881, 9816, 20144, 7351, 3837, 2379, 12169, 44131, 2498, 44162, 3125, 24231, 3347, 54641, 3174, 44303, 3107, 43548, 2752, 4691, 42081, 2705, 44010, 2108, 43241, 2847, 43947, 2901, 2804, 44353, 3091, 44531, 2826, 44439, 2850, 44692, 2889, 44519, 2824, 44208, 2317, 2506, 44264, 1560, 44668, 3169, 44793, 2755, 2513, 3032, 44944, 2821, 44944, 2870, 45290, 2728, 45118, 2666, 45160, 2526, 45256, 1985, 1670, 2847, 45740, 2696, 45413, 45074, 2655, 45645, 1917, 2140, 2776, 45296, 2287, 23222, 1123, 2697, 535, 26883, 1855, 2441, 2453, 44723, 1709, 2449, 69998, 2654, 46042, 2965, 46165, 2147, 45883, 2771, 2427, 2645, 2433, 2525, 2667, 1245, 31751, 14328, 2318, 46525, 2111, 45728, 2112, 47008, 381, 2108, 1473, 47075, 798, 44655, 2854, 45935, 2182, 1842, 45959, 1327, 46177, 8521, 39479, 1357, 2482, 47088, 2262, 2126, 43012, 46442, 1402, 47167, 2393, 47538, 2427, 46621, 2584, 47592, 2546, 1038, 47440, 2461, 46613, 2172, 2807, 46507, 2619, 2464, 46520, 2137, 2466, 28036, 7914, 45604, 2055, 25946, 47565, 2357, 14944, 35675, 2469, 48734, 2452, 48003, 2077, 48369, 1486, 2798, 48563, 2494, 2361, 392, 52512, 27292, 25981, 28614, 27162, 28061, 26467, 25358, 27151, 28255, 28292, 28693, 27233, 28592, 24686, 28546, 28633, 28671, 27789, 28580, 25807, 28575, 27636, 28874, 28658, 28753, 28773, 25204, 28937, 28549, 28396, 27375, 28846, 28611, 28582, 27578, 28772, 28454, 26499, 23064, 23050, 23306, 23733, 24245, 17257, 24242, 24011, 23087, 25089, 26381, 26351, 25324, 26518, 26860, 26865, 25925, 28485, 28853, 28712, 27561, 28674, 28941, 28605, 27337, 28628, 28868, 27491, 28463, 28274, 28427, 27688, 28725, 28532, 28849, 28228, 27643, 27494, 27631, 26989, 27385, 28308, 25779, 23922, 23490, 25219, 24862, 24820, 23986, 25980, 25562, 25356, 25552, 26996, 26743, 25611, 26806, 26852, 24605, 23659, 22475, 23822, 23672, 25491, 25638, 24356, 26383, 25160, 26131, 26216, 27153, 26155, 26804, 27281, 25096, 26893, 28164, 28212, 28299, 27353, 26826, 28551, 28190, 28386, 27138, 28651, 28109, 27048, 28310, 28634, 28327, 25907, 21799, 28628, 26623, 28511, 27388, 28556, 28415, 28184, 28197, 27286, 28344, 23378, 17090, 13535, 12058, 13143, 13916, 15205, 15885, 16905, 17298, 18698, 19776, 20192, 20536, 21188, 21922, 23336, 22825, 24588, 25519, 27210, 27986, 28635], "x": ["2018-09-04", "2018-09-05", "2018-09-06", "2018-09-07", "2018-09-08", "2018-09-10", "2018-09-11", "2018-09-12", "2018-09-13", "2018-09-14", "2018-09-15", "2018-09-17", "2018-09-18", "2018-09-20", "2018-09-22", "2018-09-24", "2018-09-25", "2018-09-27", "2018-09-28", "2018-09-30", "2018-10-01", "2018-10-03", "2018-10-05", "2018-10-06", "2018-10-07", "2018-10-09", "2018-10-12", "2018-10-14", "2018-10-17", "2018-10-20", "2018-10-24", "2018-10-25", "2018-10-26", "2018-10-29", "2018-10-31", "2018-11-01", "2018-11-03", "2018-11-06", "2018-11-08", "2018-11-09", "2018-11-10", "2018-11-11", "2018-11-14", "2018-11-16", "2018-11-17", "2018-11-20", "2018-11-22", "2018-11-23", "2018-11-24", "2018-11-25", "2018-11-28", "2018-11-30", "2018-12-02", "2018-12-04", "2018-12-06", "2018-12-07", "2018-12-08", "2018-12-10", "2018-12-12", "2018-12-14", "2018-12-17", "2018-12-19", "2018-12-21", ...

# %%
grouped_df = db['steamusers'].aggregate([
{"$match": {}},
{"$group":  {"_id": {"$dateToString": {"format": "%Y-%m-%d", "date": "$date"}},
             "count" : { "$sum" : 1} } },
{"$sort": {"_id": 1}}
])

grouped_df = pd.DataFrame(list(grouped_df))
grouped_df.rename(columns={grouped_df.columns[0] : 'date'}, inplace=True)
grouped_df
# Out:
#            date  count
# 0    2018-12-19    119
# 1    2018-12-20    340
# 2    2018-12-21    751
# 3    2018-12-22   1021
# 4    2018-12-23    932
# 5    2018-12-24    980
# 6    2018-12-25    938
# 7    2018-12-26    924
# 8    2018-12-27   1106
# 9    2018-12-28   1287
# 10   2018-12-29   1219
# 11   2018-12-30   1176
# 12   2018-12-31   1214
# 13   2019-01-01    943
# 14   2019-01-03    346
# 15   2019-01-05    617
# 16   2019-01-06    717
# 17   2019-01-07    134
# 18   2019-01-08    170
# 19   2019-01-09    351
# 20   2019-01-10     62
# 21   2019-01-11    267
# 22   2019-01-12    363
# 23   2019-01-13    409
# 24   2019-01-14    631
# 25   2019-01-15    626
# 26   2019-01-16    628
# 27   2019-01-17    597
# 28   2019-01-18    600
# 29   2019-01-19    627
# ..          ...    ...
# 333  2019-11-19    641
# 334  2019-11-20    634
# 335  2019-11-21    629
# 336  2019-11-22    631
# 337  2019-11-23    629
# 338  2019-11-24    631
# 339  2019-11-25    627
# 340  2019-11-26    628
# 341  2019-11-27    627
# 342  2019-11-28    627
# 343  2019-11-29    629
# 344  2019-11-30    623
# 345  2019-12-01    629
# 346  2019-12-02    624
# 347  2019-12-03    628
# 348  2019-12-04    627
# 349  2019-12-05    629
# 350  2019-12-06    631
# 351  2019-12-07    629
# 352  2019-12-08    627
# 353  2019-12-09    627
# 354  2019-12-10    628
# 355  2019-12-11    628
# 356  2019-12-12    639
# 357  2019-12-13    638
# 358  2019-12-14    632
# 359  2019-12-15    629
# 360  2019-12-16    631
# 361  2019-12-17    557
# 362  2019-12-18    243
#
# [363 rows x 2 columns]

# %% [markdown]
# ## These are the number of records we have per day for the `steamusers` Mongo collection.  This is created using the `steamusers.py` script.

# %%
# https://plot.ly/python/bar-charts/

data = [Bar(
        x=grouped_df['date'],
        y=grouped_df['count']
    )]

layout = Layout(
        title='Distribution of Records Per Day for steamusers',
        xaxis=dict(
            title='Date'
        ),
        yaxis=dict(
            title='Records Count'
        )
    )

fig = Figure(data=data, layout=layout)

iplot(fig)
# Out:
# <div id="9e8415b2-ce67-4a1b-9258-978a2410a20f" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("9e8415b2-ce67-4a1b-9258-978a2410a20f", [{"uid": "941eb228-bde7-4d44-8262-74582725ec2a", "y": [119, 340, 751, 1021, 932, 980, 938, 924, 1106, 1287, 1219, 1176, 1214, 943, 346, 617, 717, 134, 170, 351, 62, 267, 363, 409, 631, 626, 628, 597, 600, 627, 629, 630, 628, 629, 754, 755, 622, 623, 621, 621, 626, 629, 628, 520, 348, 452, 625, 620, 622, 622, 625, 629, 624, 631, 627, 626, 624, 600, 607, 630, 633, 642, 635, 628, 626, 563, 506, 563, 622, 604, 640, 643, 630, 628, 631, 629, 630, 641, 642, 701, 728, 620, 622, 625, 627, 338, 297, 586, 625, 567, 565, 625, 628, 627, 470, 467, 460, 427, 593, 323, 13, 295, 619, 871, 868, 716, 724, 640, 622, 620, 623, 625, 501, 500, 624, 630, 627, 628, 615, 513, 778, 874, 627, 624, 637, 636, 628, 578, 552, 608, 863, 848, 459, 465, 631, 623, 630, 711, 709, 647, 361, 317, 572, 603, 640, 836, 846, 645, 344, 282, 568, 351, 327, 620, 640, 629, 575, 445, 497, 629, 632, 397, 353, 588, 604, 607, 631, 544, 543, 629, 640, 877, 883, 387, 350, 550, 302, 325, 602, 647, 635, 618, 631, 628, 621, 537, 465, 401, 776, 853, 661, 631, 633, 635, 363, 49, 277, 893, 1184, 917, 906, 872, 695, 1021, 1456, 1136, 624, 630, 630, 613, 609, 612, 635, 854, 855, 628, 621, 620, 627, 624, 628, 619, 628, 669, 1125, 1076, 626, 626, 626, 624, 609, 605, 625, 625, 623, 619, 621, 614, 626, 629, 566, 566, 627, 680, 800, 745, 623, 621, 626, 619, 627, 616, 626, 618, 625, 620, 625, 624, 624, 625, 622, 619, 625, 623, 625, 614, 626, 635, 636, 621, 619, 618, 624, 625, 629, 630, 631, 622, 628, 624, 626, 627, 625, 621, 628, 617, 625, 625, 623, 625, 625, 625, 626, 632, 639, 630, 623, 852, 850, 621, 687, 681, 626, 626, 621, 627, 626, 626, 621, 625, 624, 629, 628, 631, 632, 628, 616, 642, 630, 625, 635, 716, 714, 625, 625, 605, 625, 705, 707, 623, 622, 625, 635, 641, 634, 629, 631, 629, 631, 627, 628, 627, 627, 629, 623, 629, 624, 628, 627, 629, 631, 629, 627, 627, 628, 628, 639, 638, 632, 629, 631, 557, 243], "x": ["2018-12-19", "2018-12-20", "2018-12-21", "2018-12-22", "2018-12-23", "2018-12-24", "2018-12-25", "2018-12-26", "2018-12-27", "2018-12-28", "2018-12-29", "2018-12-30", "2018-12-31", "2019-01-01", "2019-01-03", "2019-01-05", "2019-01-06", "2019-01-07", "2019-01-08", "2019-01-09", "2019-01-10", "2019-01-11", "2019-01-12", "2019-01-13", "2019-01-14", "2019-01-15", "2019-01-16", "2019-01-17", "2019-01-18", "2019-01-19", "2019-01-20", "2019-01-21", "2019-01-22", "2019-01-23", "2019-01-24", "2019-01-25", "2019-01-26", "2019-01-27", "2019-01-28", "2019-01-29", "2019-01-30", "2019-01-31", "2019-02-01", "2019-02-02", "2019-02-03", "2019-02-04", "2019-02-05", "2019-02-06", "2019-02-07", "2019-02-08", "2019-02-09", "2019-02-10", "2019-02-11", "2019-02-12", "2019-02-13", "2019-02-14", "2019-02-15", "2019-02-16", "2019-02-17", "2019-02-18", "2019-02-19", "2019-02-20", "2019-02-21", "2019-02-22", "2019-02-23", "2019-02-24", "2019-02-25", "2019-02-26", "2019-02-27", "2019-02-28", "2019-03-01", "2019-03-02", "2019-03-03", "2019-03-04", "2019-03-05", "2019-03-06", "2019-03-07", "2019-03-08", "2019-03-09", "2019-03-10", "2019-03-11", "2019-03-12", "2019-03-13", "2019-03-14", "2019-03-15", "2019-03-16", "2019-03-17", "2019-03-18", "2019-03-19", "2019-03-20", "2019-03-21", "2019-03-22", "2019-03-23", "2019-03-24", "2019-03-25", "2019-03-26", "2019-03-27", "2019-03-28", "2019-03-29", "2019-03-30", "2019-03-31", "2019-04-01", "2019-04-02", "2019-04-03", "2019-04-04", "2019-04-05", "2019-04-06", "2019-04-07", "2019-04-08", "2019-04-09", "2019-04-10", "2019-04-11", "2019-04-12", "2019-04-13", "2019-04-14", "2019-04-15", "2019-04-16", "2019-04-17", "2019-04-18", "2019-04-19", "2019-04-20", "2019-04-21", "2019-04-22", "2019-04-23", "2019-04-24", "2019-04-25", "2019-04-26", "2019-04-27", ...

# %%
grouped_df = db['topgames'].aggregate([
{"$match": {}},
{"$group":  {"_id": {"$dateToString": {"format": "%Y-%m-%d", "date": "$date"}},
             "count" : { "$sum" : 1} } },
{"$sort": {"_id": 1}}
])

grouped_df = pd.DataFrame(list(grouped_df))
grouped_df.rename(columns={grouped_df.columns[0] : 'date'}, inplace=True)
grouped_df
# Out:
#            date  count
# 0    2019-01-08    300
# 1    2019-01-09   2300
# 2    2019-01-10    100
# 3    2019-01-13   4000
# 4    2019-01-14   9000
# 5    2019-01-15   8400
# 6    2019-01-16   9200
# 7    2019-01-17   8500
# 8    2019-01-18   9100
# 9    2019-01-19   5200
# 10   2019-01-20   9200
# 11   2019-01-21   8500
# 12   2019-01-22   9000
# 13   2019-01-23   8400
# 14   2019-01-24   9100
# 15   2019-01-25   8600
# 16   2019-01-26   8700
# 17   2019-01-27   8600
# 18   2019-01-28   8200
# 19   2019-01-29   8700
# 20   2019-01-30   8100
# 21   2019-01-31   8600
# 22   2019-02-01   8200
# 23   2019-02-02   8600
# 24   2019-02-03   7000
# 25   2019-02-05   4100
# 26   2019-02-06   8700
# 27   2019-02-07   8200
# 28   2019-02-08   8500
# 29   2019-02-09   8200
# ..          ...    ...
# 306  2019-11-19   8600
# 307  2019-11-20   8700
# 308  2019-11-21   8500
# 309  2019-11-22   8700
# 310  2019-11-23   8600
# 311  2019-11-24   8700
# 312  2019-11-25   8800
# 313  2019-11-26   8400
# 314  2019-11-27   8700
# 315  2019-11-28   8700
# 316  2019-11-29   8700
# 317  2019-11-30   8800
# 318  2019-12-01   8500
# 319  2019-12-02   8700
# 320  2019-12-03   8800
# 321  2019-12-04   8700
# 322  2019-12-05   8700
# 323  2019-12-06   8600
# 324  2019-12-07   8600
# 325  2019-12-08   8700
# 326  2019-12-09   8700
# 327  2019-12-10   8800
# 328  2019-12-11   8700
# 329  2019-12-12   8800
# 330  2019-12-13   8700
# 331  2019-12-14   8800
# 332  2019-12-15   8800
# 333  2019-12-16   8700
# 334  2019-12-17   8600
# 335  2019-12-18   8600
#
# [336 rows x 2 columns]

# %% [markdown]
# ## These are the number of entries we have per day for the `topgames` Mongo collection.  Each query returns the current top 100 games being played.  This is run every 15 minutes.

# %%
# https://plot.ly/python/bar-charts/

data = [Bar(
        x=grouped_df['date'],
        y=grouped_df['count']
    )]

layout = Layout(
        title='Distribution of Records Per Day for topgames',
        xaxis=dict(
            title='Date'
        ),
        yaxis=dict(
            title='Records Count'
        )
    )

fig = Figure(data=data, layout=layout)

iplot(fig)
# Out:
# <div id="b98f0409-6fc6-4f92-8a44-e70056677ed7" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("b98f0409-6fc6-4f92-8a44-e70056677ed7", [{"uid": "23e91de6-0cf8-455e-8521-1f4b458788eb", "y": [300, 2300, 100, 4000, 9000, 8400, 9200, 8500, 9100, 5200, 9200, 8500, 9000, 8400, 9100, 8600, 8700, 8600, 8200, 8700, 8100, 8600, 8200, 8600, 7000, 4100, 8700, 8200, 8500, 8200, 8600, 8300, 8600, 8100, 8700, 8100, 8700, 7600, 7400, 8700, 8100, 8700, 8100, 8500, 8200, 8600, 8600, 8600, 8200, 8700, 8100, 8600, 8100, 8700, 8200, 8600, 8100, 8600, 8100, 8700, 8600, 8600, 8000, 8600, 8000, 600, 7200, 8700, 8100, 6400, 7100, 8300, 8200, 7900, 1800, 4600, 8700, 700, 8400, 7000, 8300, 8700, 7500, 8600, 8600, 5000, 8600, 8200, 8600, 8100, 8700, 8000, 8500, 8100, 8700, 8200, 8200, 8400, 3700, 8000, 8600, 8600, 7800, 8600, 7200, 7000, 8100, 2300, 7000, 6400, 5600, 4000, 3400, 8200, 8000, 7800, 7100, 7000, 4400, 6800, 7200, 3800, 5500, 8500, 7600, 8200, 8200, 5800, 5900, 4400, 8700, 8700, 8100, 8700, 8300, 8700, 8100, 8600, 4500, 7800, 8600, 4200, 8400, 8300, 3800, 6900, 7000, 4400, 8200, 8400, 8000, 1900, 4300, 4700, 6700, 8100, 8700, 8400, 8300, 8300, 8000, 8700, 6800, 7400, 8700, 6700, 8400, 8000, 8500, 8000, 1800, 7000, 8000, 8100, 8700, 8700, 8700, 8800, 8300, 8600, 8800, 8700, 8700, 8800, 8700, 7800, 8800, 8600, 8700, 8700, 8800, 8100, 8700, 8700, 8800, 8700, 8800, 8700, 8500, 8600, 8800, 8700, 8700, 8700, 8700, 8700, 8700, 8700, 8600, 8800, 8600, 8800, 8600, 8700, 8600, 6800, 8500, 8500, 8600, 8700, 8700, 8700, 8700, 8700, 8700, 8700, 8700, 8800, 8600, 8700, 8700, 8600, 8700, 8700, 8600, 8700, 8600, 8700, 8500, 8800, 8600, 8800, 8700, 8700, 8600, 8700, 8700, 8500, 8300, 8400, 8400, 8700, 8800, 8700, 8403, 8600, 8700, 8800, 8700, 8700, 8600, 8700, 8700, 8600, 8700, 8700, 8800, 8600, 8800, 8700, 8700, 8700, 8600, 8500, 8500, 8600, 8700, 8700, 8700, 8700, 8700, 8700, 8700, 8300, 7800, 8500, 8700, 8700, 8500, 8600, 8400, 8700, 8700, 8700, 8700, 8700, 8500, 8800, 8700, 8600, 8700, 8300, 6900, 8600, 8600, 8500, 8600, 8700, 8500, 8700, 8600, 8700, 8800, 8400, 8700, 8700, 8700, 8800, 8500, 8700, 8800, 8700, 8700, 8600, 8600, 8700, 8700, 8800, 8700, 8800, 8700, 8800, 8800, 8700, 8600, 8600], "x": ["2019-01-08", "2019-01-09", "2019-01-10", "2019-01-13", "2019-01-14", "2019-01-15", "2019-01-16", "2019-01-17", "2019-01-18", "2019-01-19", "2019-01-20", "2019-01-21", "2019-01-22", "2019-01-23", "2019-01-24", "2019-01-25", "2019-01-26", "2019-01-27", "2019-01-28", "2019-01-29", "2019-01-30", "2019-01-31", "2019-02-01", "2019-02-02", "2019-02-03", "2019-02-05", "2019-02-06", "2019-02-07", "2019-02-08", "2019-02-09", "2019-02-10", "2019-02-11", "2019-02-12", "2019-02-13", "2019-02-14", "2019-02-15", "2019-02-16", "2019-02-17", "2019-02-18", "2019-02-19", "2019-02-20", "2019-02-21", "2019-02-22", "2019-02-23", "2019-02-24", "2019-02-25", "2019-02-26", "2019-02-27", "2019-02-28", "2019-03-01", "2019-03-02", "2019-03-03", "2019-03-04", "2019-03-05", "2019-03-06", "2019-03-07", "2019-03-08", "2019-03-09", "2019-03-10", "2019-03-11", "2019-03-12", "2019-03-13", "2019-03-14", "2019-03-15", "2019-03-16", "2019-03-17", "2019-03-18", "2019-03-19", "2019-03-20", "2019-03-21", "2019-03-22", "2019-03-23", "2019-03-24", "2019-03-25", "2019-03-26", "2019-03-27", "2019-03-28", "2019-03-29", "2019-03-30", "2019-03-31", "2019-04-02", "2019-04-03", "2019-04-04", "2019-04-05", "2019-04-06", "2019-04-07", "2019-04-08", "2019-04-09", "2019-04-10", "2019-04-11", "2019-04-12", "2019-04-13", "2019-04-14", "2019-04-15", "2019-04-16", "2019-04-17", "2019-04-18", "2019-04-19", "2019-04-20", "2019-04-21", "2019-04-22", "2019-04-23", "2019-04-24", "2019-04-25", "2019-04-26", "2019-04-27", "2019-04-28", "2019-04-29", "2019-04-30", "2019-05-01", "2019-05-02", "2019-05-03", "2019-05-04", "2019-05-05", "2019-0 ...

# %%
grouped_df = db['apps'].aggregate([
{"$match": {}},
{"$group":  {"_id": {"$dateToString": {"format": "%Y-%m-%d", "date": "$reviews.last_updated"}},
             "count" : { "$sum" : 1} } },
{"$sort": {"_id": 1}}
])

grouped_df = pd.DataFrame(list(grouped_df))
grouped_df.rename(columns={grouped_df.columns[0] : 'date'}, inplace=True)
grouped_df
# Out:
#          date  count
# 0        None  91371
# 1  2020-07-25     51

# %% [markdown]
# ## These are the number of Steam games where we have review information from Steam and when they were last updated

# %%
# https://plot.ly/python/bar-charts/

data = [Bar(
        x=grouped_df['date'],
        y=grouped_df['count']
    )]

layout = Layout(
        title='Distribution of Steam game reviews per day',
        xaxis=dict(
            title='Date'
        ),
        yaxis=dict(
            title='Records Count'
        )
    )

fig = Figure(data=data, layout=layout)

iplot(fig)
# Out:
# <div id="0abfdfbc-f430-417d-934e-badcca14c184" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("0abfdfbc-f430-417d-934e-badcca14c184", [{"uid": "d6111c9f-e078-4ee1-b1b9-4042f8796f52", "y": [91371, 51], "x": [null, "2020-07-25"], "type": "bar"}], {"title": {"text": "Distribution of Steam game reviews per day"}, "xaxis": {"title": {"text": "Date"}}, "yaxis": {"title": {"text": "Records Count"}}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("0abfdfbc-f430-417d-934e-badcca14c184"));});</script>

# %%
steam_grouped_df = db['opencritic'].aggregate([
{"$match": {"steamId": {"$exists": True, "$ne": None}}},
{"$group":  {"_id": {"$dateToString": {"format": "%Y-%m-%d", "date": "$date"}},
             "count" : { "$sum" : 1} } },
{"$sort": {"_id": 1}}
])

steam_grouped_df = pd.DataFrame(list(steam_grouped_df))
steam_grouped_df.rename(columns={steam_grouped_df.columns[0] : 'date'}, inplace=True)

nonsteam_grouped_df = db['opencritic'].aggregate([
{"$match": {"$or": [{"steamId": {"$exists": False}}, {"steamId": None}]}},
{"$group":  {"_id": {"$dateToString": {"format": "%Y-%m-%d", "date": "$date"}},
             "count" : { "$sum" : 1} } },
{"$sort": {"_id": 1}}
])

nonsteam_grouped_df = pd.DataFrame(list(nonsteam_grouped_df))
nonsteam_grouped_df.rename(columns={nonsteam_grouped_df.columns[0] : 'date'}, inplace=True)

print(steam_grouped_df)
print(nonsteam_grouped_df)
# Out:
#           date  count
# 0   2019-12-04     11
# 1   2019-12-05    351
# 2   2019-12-06    345
# 3   2019-12-07    353
# 4   2019-12-08    345
# 5   2019-12-09    336
# 6   2019-12-10    357
# 7   2019-12-11    325
# 8   2019-12-12    329
# 9   2019-12-13    330
# 10  2019-12-14    336
# 11  2019-12-15    336
# 12  2019-12-16    347
# 13  2019-12-17    338
# 14  2019-12-18    333
#           date  count
# 0   2019-12-04     11
# 1   2019-12-05    209
# 2   2019-12-06    213
# 3   2019-12-07    195
# 4   2019-12-08    204
# 5   2019-12-09    215
# 6   2019-12-10    202
# 7   2019-12-11    226
# 8   2019-12-12    200
# 9   2019-12-13    224
# 10  2019-12-14    214
# 11  2019-12-15    216
# 12  2019-12-16    208
# 13  2019-12-17    214
# 14  2019-12-18    193

# %% [markdown]
# ## This is the breakdown of OpenCritic data we have by last accessed/updated date.

# %%
# https://plot.ly/python/bar-charts/#stacked-bar-chart

steamTrace = Bar(
    x=steam_grouped_df['date'],
    y=steam_grouped_df['count'],
    name='Games w/steamId'
)
nonSteamTrace = Bar(
    x=nonsteam_grouped_df['date'],
    y=nonsteam_grouped_df['count'],
    name='Games without steamId'
)

data = [steamTrace, nonSteamTrace]

layout = Layout(
        title='Distribution of OpenCritic Records Per Day Grouped By steamId',
        xaxis=dict(
            title='Date'
        ),
        yaxis=dict(
            title='Records Count'
        ),
        barmode='stack'
    )

fig = Figure(data=data, layout=layout)

iplot(fig)
# Out:
# <div id="0d591c09-4d34-477b-9841-1ac83e51f2fd" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("0d591c09-4d34-477b-9841-1ac83e51f2fd", [{"x": ["2019-12-04", "2019-12-05", "2019-12-06", "2019-12-07", "2019-12-08", "2019-12-09", "2019-12-10", "2019-12-11", "2019-12-12", "2019-12-13", "2019-12-14", "2019-12-15", "2019-12-16", "2019-12-17", "2019-12-18"], "type": "bar", "y": [11, 351, 345, 353, 345, 336, 357, 325, 329, 330, 336, 336, 347, 338, 333], "name": "Games w/steamId", "uid": "3e74eb48-bc5b-477f-a3f8-e5499b41fe34"}, {"x": ["2019-12-04", "2019-12-05", "2019-12-06", "2019-12-07", "2019-12-08", "2019-12-09", "2019-12-10", "2019-12-11", "2019-12-12", "2019-12-13", "2019-12-14", "2019-12-15", "2019-12-16", "2019-12-17", "2019-12-18"], "type": "bar", "y": [11, 209, 213, 195, 204, 215, 202, 226, 200, 224, 214, 216, 208, 214, 193], "name": "Games without steamId", "uid": "084c878f-2f30-48c2-b821-33dc5b737107"}], {"title": {"text": "Distribution of OpenCritic Records Per Day Grouped By steamId"}, "xaxis": {"title": {"text": "Date"}}, "barmode": "stack", "yaxis": {"title": {"text": "Records Count"}}}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("0d591c09-4d34-477b-9841-1ac83e51f2fd"));});</script>

# %% [markdown]
# ## This is counts of Twitch records by day grouped by a tie to Steam

# %%
steam_grouped_df = db['twitchhistorical'].aggregate([
{"$match": {"steamId": {"$exists": True}}},
{"$group":  {"_id": {"$dateToString": {"format": "%Y-%m-%d", "date": "$date"}},
             "count" : { "$sum" : 1} } },
{"$sort": {"_id": 1}}
])

steam_grouped_df = pd.DataFrame(list(steam_grouped_df))
steam_grouped_df.rename(columns={steam_grouped_df.columns[0] : 'date'}, inplace=True)

nonsteam_grouped_df = db['twitchhistorical'].aggregate([
{"$match": {"steamId": {"$exists": False}}},
{"$group":  {"_id": {"$dateToString": {"format": "%Y-%m-%d", "date": "$date"}},
             "count" : { "$sum" : 1} } },
{"$sort": {"_id": 1}}
])

nonsteam_grouped_df = pd.DataFrame(list(nonsteam_grouped_df))
nonsteam_grouped_df.rename(columns={nonsteam_grouped_df.columns[0] : 'date'}, inplace=True)

# https://plot.ly/python/bar-charts/#stacked-bar-chart

steamTrace = Bar(
    x=steam_grouped_df['date'],
    y=steam_grouped_df['count'],
    name='Games w/steamId'
)
nonSteamTrace = Bar(
    x=nonsteam_grouped_df['date'],
    y=nonsteam_grouped_df['count'],
    name='Games without steamId'
)

data = [steamTrace, nonSteamTrace]

layout = Layout(
        title='Distribution of Twitch Records Per Day Grouped By steamId',
        xaxis=dict(
            title='Date'
        ),
        yaxis=dict(
            title='Records Count'
        ),
        barmode='stack'
    )

fig = Figure(data=data, layout=layout)

iplot(fig)
# Out:
# <div id="088383fc-81cf-4106-b25e-9dcbc3ac6066" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("088383fc-81cf-4106-b25e-9dcbc3ac6066", [{"x": ["2019-07-14", "2019-07-15", "2019-07-16", "2019-07-17", "2019-07-18", "2019-07-19", "2019-07-20", "2019-07-21", "2019-07-22", "2019-07-23", "2019-07-24", "2019-07-25", "2019-07-26", "2019-07-27", "2019-07-28", "2019-07-29", "2019-07-30", "2019-07-31", "2019-08-01", "2019-08-02", "2019-08-03", "2019-08-04", "2019-08-05", "2019-08-06", "2019-08-07", "2019-08-08", "2019-08-09", "2019-08-10", "2019-08-11", "2019-08-12", "2019-08-13", "2019-08-14", "2019-08-15", "2019-08-16", "2019-08-17", "2019-08-18", "2019-08-19", "2019-08-20", "2019-08-21", "2019-08-22", "2019-08-23", "2019-08-24", "2019-08-25", "2019-08-26", "2019-08-27", "2019-08-28", "2019-08-29", "2019-08-30", "2019-08-31", "2019-09-01", "2019-09-02", "2019-09-03", "2019-09-04", "2019-09-05", "2019-09-06", "2019-09-07", "2019-09-08", "2019-09-09", "2019-09-10", "2019-09-11", "2019-09-12", "2019-09-13", "2019-09-14", "2019-09-15", "2019-09-16", "2019-09-17", "2019-09-18", "2019-09-19", "2019-09-20", "2019-09-21", "2019-09-22", "2019-09-23", "2019-09-24", "2019-09-25", "2019-09-26", "2019-09-27", "2019-09-28", "2019-09-29", "2019-09-30", "2019-10-01", "2019-10-02", "2019-10-03", "2019-10-04", "2019-10-05", "2019-10-06", "2019-10-07", "2019-10-08", "2019-10-09", "2019-10-10", "2019-10-11", "2019-10-12", "2019-10-13", "2019-10-14", "2019-10-15", "2019-10-16", "2019-10-17", "2019-10-18", "2019-10-19", "2019-10-20", "2019-10-21", "2019-10-22", "2019-10-23", "2019-10-24", "2019-10-25", "2019-10-26", "2019-10-27", "2019-10-28", "2019-10-29", "2019-10-30", "2019-10-31", "2019-11-01", "2019-11-02", "2019-11-03", "2019-11-04", "2019-11-05", "2019-11-06", "2019-11-07", "2019-11-08", "2019-11-09", "2019-11-10", "2019-11-11", "2019-11-12", "2019-11-13", "2019-11-14", "2019-11-15", "2019-11-16", "2019-11-17", "2019-11-18", "2019-11-19", "2019-11-20", "2019-11-21", "2019-11-22", "2019-11-23", "2019-11-24", "2019-11-25", "2019-11-26", "2019-11-27", "2019-11-28", "2019-11-29", "2019-11-30", "2019-12-01", "2019-12-02", "2019-12-03", "2019-12-04", "2019-12-05", "2019-12-06", "2019-12-07", "2019-12-08", "2019-12-09", "2019-12-10", "2019-12-11", "2019-12-12", "2019-12-13", "2019-12-14", "2019-12-15", "2019-12-16", "2019-12-17", "2019-12-18"], "type": "bar", "y": [24004, 16988, 18423, 18033, 19570, 17635, 17365, 14602, 17003, 16842, 4636, 7878, 7679, 5402, 7767, 5038, 8103, 7446, 4973, 7904, 8347, 5043, 7491, 8098, 4942, 7569, 7905, 4677, 7870, 7759, 5253, 8086, 5012, 7276, 8014, 4765, 7461, 7416, 4703, 7671, 5081, 7926, 5081, 7711, 7659, 4917, 7515, 7925, 5854, 8591, 5299, 7855, 7892, 5121, 7951, 8501, 5322, 8582, 8629, 5326, 8840, 5040, 8060, 7973, 4458, 7984, 7195, 4812, 7097, 7254, 4847, 7107, 4645, 8111, 7715, 4937, 7689, 7598, 4518, 7287, 6589, 4291, 7376, 4717, 7220, 6806, 4576, 7506, 7084, 4562, 7351, 7130, 4358, 7045, 4421, 6881, 4446, 4803, 6920, 4450, 7379, 7371, 4366, 7605, 7585, 4920, 7708, 7728, 4327, 7670, 5129, 7145, 7838, 4291, 7129, 6957, 4814, 7580, 5076, 6980, 7024, 4292, 7004, 4322, 5104, 4382, 7378, 6780, 4585, 7332, 4403, 6626, 7503, 4558, 6845, 7688, 4521, 7427, 7380, 5066, 7505, 7004, 4923, 7567, 4848, 7605, 7861, 4983, 7195, 7430, 4581, 7415, 8074, 4834, 8430, 8242, 5481, 8384], "name": "Games w/steamId", "uid": "cd274763-028f-4224-817f-9a9f7cd6b89b"}, {"x": ["2019-07-14", "2019-07-15", "2019-07-16", "2019-07-17", "2019-07-18", "2019-07-19", "2019-07-20", "2019-07-21", "2019-07-22", "2019-07-23", "2019-07-24", "2019-07-25", "2019-07-26", "2019-07-27", "2019-07-28", "2019-07-29", "2019-07-30", "2019-07-31", "2019-08-01", "2019-08-02", "2019-08-03", "2019-08-04", "2019-08-05", "2019-08-06", "2019-08-07", "2019-08-08", "2019-08-09", "2019-08-10", "2 ...

# %% [markdown]
# ## Storage and disk usage information

# %%
for collection in db.list_collection_names():
    stats = db.command("collstats", str(collection))
    print(collection + " size: " + common.sizeof_fmt(stats['size']))

print("--------------------")
stats = db.command("dbstats")
print("Total Database Size: " + common.sizeof_fmt(stats['dataSize']))
# Out:
# opencritic size: 110.8 MiB
# topgames size: 475.6 MiB
# pricehistory size: 865.3 MiB
# twitchhistorical size: 1.2 GiB
# apps size: 608.1 MiB
# steamusers size: 16.7 MiB
# --------------------
# Total Database Size: 3.2 GiB

# %% [markdown]
# ## Check index size across collections

# %%
total_index = 0
for collection in db.list_collection_names():
    stats = db.command("collstats", str(collection))
    total_index = total_index + stats['totalIndexSize']
    print(collection + " size: " + common.sizeof_fmt(stats['totalIndexSize']))

print("--------------------")
print("Total Index Size: " + common.sizeof_fmt(total_index))
# Out:
# opencritic size: 392.0 KiB
# topgames size: 52.1 MiB
# pricehistory size: 256.3 MiB
# twitchhistorical size: 108.0 MiB
# apps size: 7.1 MiB
# steamusers size: 7.0 MiB
# --------------------
# Total Index Size: 430.8 MiB
